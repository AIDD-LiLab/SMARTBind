# %% [markdown]
# # Ligand Swapping test
#
# This notebook implements ligand swapping test for SMARTBind on the RNAmigos1 dataset.
# Instead of swapping RNA, here we **swap the positive ligand** across entries
# while keeping each RNA and its decoys fixed.
#
# **Swap logic**: For each fold, collect all unique ligands. Build a global derangement permutation σ
# over ligands. For each entry `(RNA_i, ligand_i, decoys_i)`, the swapped evaluation uses
# `(RNA_i, ligand_σ(i), decoys_i)` — i.e. the RNA sees a wrong positive ligand but its own decoys.
#
# **1: Target-level (Local) AuROC**
# - Group by RNA target, compute per-target AuROC, then average across targets
#
# **2: Global AuROC**
# - Pool all (label, score) into one flat list per fold, compute a single AuROC
#
# Both protocols are applied to PDB decoys and DecoyFinder decoys.
#
# The script can be reproduced with the pretrained weight downloaded from [here](https://drive.google.com/file/d/1WBOch8fqVHrNT09gJlG0Z3TkTtI8BTxW/view?usp=sharing), and RNAmigos1 10-fold cross-validation dataset downloaded from [here](https://drive.google.com/file/d/1hV07dJjQcFaiKO5MUan7Ey1F6LpUIhA4/view?usp=sharing), although the swapping results are already provided below.

# %%
import sys
sys.path.append('../../../..')
import os
from smartbind.preprocess import build_val_test_set
from smartbind.dataloader import RLDataLoader, RLDataset
from smartbind import load_smartbind_models
from smartbind.preprocess import convert_smiles_to_pf2

import tqdm
from smartbind.model.margin import sigmoid_cosine_distance_test
import torch
import numpy as np
from sklearn.metrics import roc_auc_score
from collections import defaultdict

# %%
current_path = 'rnamigos_10fd_with_decoys.pkl'
topk_decoy = 100
batch_size = 24
num_workers = 2
device = 'cpu'
K_SWAP_REPETITIONS = 5  # Number of swap repetitions for statistical robustness
RANDOM_SEED = 42

# %% [markdown]
# ## Helper functions

# %%
def normalize_scores(scores):
    """Min-max normalize scores to [0, 1]."""
    scores = np.array(scores)
    s_min, s_max = scores.min(), scores.max()
    if s_max > s_min:
        return (scores - s_min) / (s_max - s_min)
    return scores


def compute_scores_for_pair(smartbind_model, rna_emb, match_smol_fp, decoy_fps):
    """
    Given a pre-computed RNA embedding, compute similarity scores for
    the true ligand and all decoy ligands.
    
    Returns:
        match_score: float, similarity score for the true binder
        decoy_scores: list of float, similarity scores for decoys
    """
    anchor = rna_emb.squeeze(1)
    
    # True ligand score
    match_tok = smartbind_model.inference_list_smols([match_smol_fp])[0].unsqueeze(0)
    match_score = sigmoid_cosine_distance_test(anchor, match_tok).item()
    
    # Decoy scores
    decoy_scores = []
    decoy_tok_list = smartbind_model.inference_list_smols(decoy_fps)
    for dtok in decoy_tok_list:
        dtok = dtok.unsqueeze(0)
        ds = sigmoid_cosine_distance_test(anchor, dtok).item()
        decoy_scores.append(ds)
    
    return match_score, decoy_scores


def compute_rank_percentile(match_score, decoy_scores):
    """Compute rank percentile of the true binder among decoys."""
    rank = sum(1 for ds in decoy_scores if match_score <= ds)
    return (len(decoy_scores) + 1 - rank) / (len(decoy_scores) + 1)


def compute_pair_auroc(match_score, decoy_scores):
    """Compute AUROC for a single pair (1 positive + N decoys), with normalization."""
    scores = [match_score] + decoy_scores
    labels = [1] + [0] * len(decoy_scores)
    scores_norm = normalize_scores(scores)
    return roc_auc_score(labels, scores_norm)

# %% [markdown]
# ## Collect data + Original & Ligand-Swapped evaluation
#
# For each fold, we:
# 1. Load the model
# 2. Iterate through all validation pairs, cache RNA embeddings
# 3. Compute original scores
# 4. Build global derangement over **ligands** (match_smol_fp), K repetitions
# 5. For each swapped repetition: pair each RNA with a wrong ligand + its original decoys

# %% [markdown]
# ### PDB Decoys

# %%
# ============================================================
# PDB Decoys — Collect data + original & ligand-swapped evaluation
# ============================================================

all_fold_results_pdb = {}  # fold_num -> dict of results

for current_fold_num in range(1, 11):
    print(f'\n{"="*60}')
    print(f'Processing fold {current_fold_num} (PDB Decoys — Ligand Swap)')
    print(f'{"="*60}')
    
    val_rna_seq_list, val_match_smol_list, val_rna_name_list, val_match_smol_name_list, \
        val_binding_index_list, val_match_smol_fp_list, train_rna_seq_list, train_match_smol_list, \
        train_rna_name_list, train_match_smol_name_list, train_binding_index_list, \
        train_match_smol_fp_list, match_pair_dict = build_val_test_set(
            fold_num=current_fold_num - 1,
            dict_path=current_path,
            topk_decoy=topk_decoy)
    
    val_dataset = RLDataset(
        rna_sequences=val_rna_seq_list,
        rna_sequences_names=val_rna_name_list,
        match_smols=val_match_smol_fp_list,
        match_smols_names=val_match_smol_name_list,
        non_binding_index_list=val_binding_index_list,
        is_val=True)
    val_dataloader = RLDataLoader(
        dataset=val_dataset,
        batch_size=batch_size,
        num_workers=num_workers,
        if_shuffle=False)
    
    weight_path = f'weights/fold{current_fold_num}.pth'
    smartbind_model = load_smartbind_models(
        model_path=weight_path, device=device, vs_mode=True)
    smartbind_model.eval()
    
    # Collect all data for this fold
    fold_entries = []
    rna_emb_cache = {}
    
    with torch.no_grad():
        for batch in tqdm.tqdm(val_dataloader.dataloader, desc=f'Fold {current_fold_num}'):
            rna_sequences, match_smols, decoy_smols_list, _, _, _ = batch
            
            for rna_seq, match_smol, decoy_smols in zip(
                rna_sequences, match_smols, decoy_smols_list
            ):
                if len(decoy_smols) == 0:
                    continue
                
                rna_name = rna_seq[0]
                rna_seq_str = rna_seq[1]
                match_smol_name = match_smol[0]
                match_smol_fp = match_smol[1]
                
                # Cache RNA embedding
                if rna_name not in rna_emb_cache:
                    rna_emb = smartbind_model.inference_single_rna(rna_seq_str)
                    rna_emb_cache[rna_name] = rna_emb
                
                fold_entries.append({
                    'rna_name': rna_name,
                    'rna_seq': rna_seq_str,
                    'match_smol_name': match_smol_name,
                    'match_smol_fp': match_smol_fp,
                    'decoy_fps': list(decoy_smols),
                })
    
    # ===== Original (non-swapped) evaluation =====
    rna_names = []
    original_scores = []   # list of (match_score, decoy_scores) per entry
    original_rank_percentiles = []
    original_pair_aurocs = []
    
    with torch.no_grad():
        for entry in tqdm.tqdm(fold_entries, desc='Original eval'):
            rna_emb = rna_emb_cache[entry['rna_name']]
            match_score, decoy_scores = compute_scores_for_pair(
                smartbind_model, rna_emb, entry['match_smol_fp'], entry['decoy_fps'])
            
            rna_names.append(entry['rna_name'])
            original_scores.append((match_score, decoy_scores))
            original_rank_percentiles.append(compute_rank_percentile(match_score, decoy_scores))
            original_pair_aurocs.append(compute_pair_auroc(match_score, decoy_scores))
    
    # ===== Ligand-Swapped evaluation (K repetitions, global permutation over ligands) =====
    # Build list of unique ligand fingerprints (keyed by match_smol_name)
    unique_ligand_names = list(set(e['match_smol_name'] for e in fold_entries))
    ligand_fp_map = {}  # match_smol_name -> match_smol_fp
    for e in fold_entries:
        if e['match_smol_name'] not in ligand_fp_map:
            ligand_fp_map[e['match_smol_name']] = e['match_smol_fp']
    
    n_ligands = len(unique_ligand_names)
    print(f'Unique ligands in fold {current_fold_num}: {n_ligands}')
    
    swap_rep_results = []
    rng = np.random.RandomState(RANDOM_SEED + current_fold_num)
    
    for k in range(K_SWAP_REPETITIONS):
        # Build global derangement sigma over ligand names
        permuted_ligand_names = unique_ligand_names.copy()
        rng.shuffle(permuted_ligand_names)
        if n_ligands > 1:
            while any(permuted_ligand_names[i] == unique_ligand_names[i] for i in range(n_ligands)):
                rng.shuffle(permuted_ligand_names)
        sigma = dict(zip(unique_ligand_names, permuted_ligand_names))
        
        # For each entry, use the ORIGINAL RNA but the SWAPPED ligand
        swapped_scores_k = []
        swapped_rank_percentiles_k = []
        swapped_pair_aurocs_k = []
        
        with torch.no_grad():
            for entry in fold_entries:
                rna_emb = rna_emb_cache[entry['rna_name']]  # original RNA
                swapped_ligand_name = sigma[entry['match_smol_name']]
                swapped_ligand_fp = ligand_fp_map[swapped_ligand_name]
                
                # Score: original RNA + swapped ligand + original decoys
                match_score, decoy_scores = compute_scores_for_pair(
                    smartbind_model, rna_emb,
                    swapped_ligand_fp, entry['decoy_fps'])
                
                swapped_scores_k.append((match_score, decoy_scores))
                swapped_rank_percentiles_k.append(compute_rank_percentile(match_score, decoy_scores))
                swapped_pair_aurocs_k.append(compute_pair_auroc(match_score, decoy_scores))
        
        swap_rep_results.append({
            'scores': swapped_scores_k,
            'rank_percentiles': swapped_rank_percentiles_k,
            'pair_aurocs': swapped_pair_aurocs_k,
        })
        print(f'  Swap repetition {k+1}/{K_SWAP_REPETITIONS} done.')
    
    all_fold_results_pdb[current_fold_num] = {
        'rna_names': rna_names,
        'original_scores': original_scores,
        'original_rank_percentiles': original_rank_percentiles,
        'original_pair_aurocs': original_pair_aurocs,
        'swap_rep_results': swap_rep_results,
        'unique_ligand_names': unique_ligand_names,
        'n_entries': len(fold_entries),
    }
    
    print(f'Fold {current_fold_num} done. Entries: {len(fold_entries)}')
# Out:
# ============================================================
# Processing fold 1 (PDB Decoys — Ligand Swap)
# ============================================================
# Global seed set to 42
# Not loaded: ['smol_binding_featurizer.0.weight', 'smol_binding_featurizer.0.bias', 'smol_binding_featurizer.1.weight', 'smol_binding_featurizer.1.bias', 'smol_binding_featurizer.1.running_mean', 'smol_binding_featurizer.1.running_var', 'smol_binding_featurizer.1.num_batches_tracked', 'binding_site_featurizer.cross_attention.smol_projection.weight', 'binding_site_featurizer.cross_attention.smol_projection.bias', 'binding_site_featurizer.cross_attention.projection.weight', 'binding_site_featurizer.cross_attention.projection.bias', 'binding_site_featurizer.cross_attention.batch_norm_projection.weight', 'binding_site_featurizer.cross_attention.batch_norm_projection.bias', 'binding_site_featurizer.cross_attention.batch_norm_projection.running_mean', 'binding_site_featurizer.cross_attention.batch_norm_projection.running_var', 'binding_site_featurizer.cross_attention.batch_norm_projection.num_batches_tracked', 'binding_site_featurizer.cross_attention.self_attention.0.0.in_proj_weight', 'binding_site_featurizer.cross_attention.self_attention.0.0.in_proj_bias', 'binding_site_featurizer.cross_attention.self_attention.0.0.out_proj.weight', 'binding_site_featurizer.cross_attention.self_attention.0.0.out_proj.bias', 'binding_site_featurizer.cross_attention.self_attention.0.1.weight', 'binding_site_featurizer.cross_attention.self_attention.0.1.bias', 'binding_site_featurizer.cross_attention.mlp.0.weight', 'binding_site_featurizer.cross_attention.mlp.0.bias', 'binding_site_featurizer.cross_attention.mlp.1.weight', 'binding_site_featurizer.cross_attention.mlp.1.bias', 'binding_site_featurizer.cross_attention.mlp.1.running_mean', 'binding_site_featurizer.cross_attention.mlp.1.running_var', 'binding_site_featurizer.cross_attention.mlp.1.num_batches_tracked', 'binding_site_featurizer.cross_attention.mlp.4.weight', 'binding_site_featurizer.cross_attention.mlp.4.bias', 'binding_site_featurizer.cross_attention.mlp.5.weight', 'binding_site_featurizer.cross_attention.mlp.5.bias', 'binding_site_featurizer.cross_attention.mlp.5.running_mean', 'binding_site_featurizer.cross_attention.mlp.5.running_var', 'binding_site_featurizer.cross_attention.mlp.5.num_batches_tracked', 'binding_site_featurizer.cross_attention.mlp.8.weight', 'binding_site_featurizer.cross_attention.mlp.8.bias']
# Fold 1: 100%|██████████| 3/3 [01:01<00:00, 20.50s/it]
# Original eval: 100%|██████████| 72/72 [00:01<00:00, 42.43it/s]
# Unique ligands in fold 1: 47
#   Swap repetition 1/5 done.
#   Swap repetition 2/5 done.
#   Swap repetition 3/5 done.
#   Swap repetition 4/5 done.
#   Swap repetition 5/5 done.
# Fold 1 done. Entries: 72
#
# ============================================================
# Processing fold 2 (PDB Decoys — Ligand Swap)
# ============================================================
# Global seed set to 42
# Not loaded: ['smol_binding_featurizer.0.weight', 'smol_binding_featurizer.0.bias', 'smol_binding_featurizer.1.weight', 'smol_binding_featurizer.1.bias', 'smol_binding_featurizer.1.running_mean', 'smol_binding_featurizer.1.running_var', 'smol_binding_featurizer.1.num_batches_tracked', 'binding_site_featurizer.cross_attention.smol_projection.weight', 'binding_site_featurizer.cross_attention.smol_projection.bias', 'binding_site_featurizer.cross_attention.projection.weight', 'binding_site_featurizer.cross_attention.projection.bias', 'binding_site_featurizer.cross_attention.batch_norm_projection.weight', 'binding_site_featurizer.cross_attention.batch_norm_projection.bias', 'binding_site_featurizer.cross_attention.batch_norm_projection.running_mean', 'binding_site_featurizer.cross_attention.batch_norm_projection.running_var', 'binding_site_featurizer.cross_attention.batch_norm_projection.num_batches_tracked', 'binding_site_featurizer.cross_attention.self_attention.0.0.in_proj_weight', 'binding_site_featurizer.cross_attention.self_attention.0.0.in_proj_bias', 'binding_site_featurizer.cross_attention.self_attention.0.0.out_proj.weight', 'binding_site_featurizer.cross_attention.self_attention.0.0.out_proj.bias', 'binding_site_featurizer.cross_attention.self_attention.0.1.weight', 'binding_site_featurizer.cross_attention.self_attention.0.1.bias', 'binding_site_featurizer.cross_attention.mlp.0.weight', 'binding_site_featurizer.cross_attention.mlp.0.bias', 'binding_site_featurizer.cross_attention.mlp.1.weight', 'binding_site_featurizer.cross_attention.mlp.1.bias', 'binding_site_featurizer.cross_attention.mlp.1.running_mean', 'binding_site_featurizer.cross_attention.mlp.1.running_var', 'binding_site_featurizer.cross_attention.mlp.1.num_batches_tracked', 'binding_site_featurizer.cross_attention.mlp.4.weight', 'binding_site_featurizer.cross_attention.mlp.4.bias', 'binding_site_featurizer.cross_attention.mlp.5.weight', 'binding_site_featurizer.cross_attention.mlp.5.bias', 'binding_site_featurizer.cross_attention.mlp.5.running_mean', 'binding_site_featurizer.cross_attention.mlp.5.running_var', 'binding_site_featurizer.cross_attention.mlp.5.num_batches_tracked', 'binding_site_featurizer.cross_attention.mlp.8.weight', 'binding_site_featurizer.cross_attention.mlp.8.bias']
# Fold 2: 100%|██████████| 4/4 [00:38<00:00,  9.66s/it]
# Original eval: 100%|██████████| 78/78 [00:01<00:00, 43.59it/s]
# Unique ligands in fold 2: 57
#   Swap repetition 1/5 done.
#   Swap repetition 2/5 done.
#   Swap repetition 3/5 done.
#   Swap repetition 4/5 done.
#   Swap repetition 5/5 done.
# Fold 2 done. Entries: 78
#
# ============================================================
# Processing fold 3 (PDB Decoys — Ligand Swap)
# ============================================================
# Global seed set to 42
# Not loaded: ['smol_binding_featurizer.0.weight', 'smol_binding_featurizer.0.bias', 'smol_binding_featurizer.1.weight', 'smol_binding_featurizer.1.bias', 'smol_binding_featurizer.1.running_mean', 'smol_binding_featurizer.1.running_var', 'smol_binding_featurizer.1.num_batches_tracked', 'binding_site_featurizer.cross_attention.smol_projection.weight', 'binding_site_featurizer.cross_attention.smol_projection.bias', 'binding_site_featurizer.cross_attention.projection.weight', 'binding_site_featurizer.cross_attention.projection.bias', 'binding_site_featurizer.cross_attention.batch_norm_projection.weight', 'binding_site_featurizer.cross_attention.batch_norm_projection.bias', 'binding_site_featurizer.cross_attention.batch_norm_projection.running_mean', 'binding_site_featurizer.cross_attention.batch_norm_projection.running_var', 'binding_site_featurizer.cross_attention.batch_norm_projection.num_batches_tracked', 'binding_site_featurizer.cross_attention.self_attention.0.0.in_proj_weight', 'binding_site_featurizer.cross_attention.self_attention.0.0.in_proj_bias', 'binding_site_featurizer.cross_attention.self_attention.0.0.out_proj.weight', 'binding_site_featurizer.cross_attention.self_attention.0.0.out_proj.bias', 'binding_site_featurizer.cross_attention.self_attention.0.1.weight', 'binding_site_featurizer.cross_attention.self_attention.0.1.bias', 'binding_site_featurizer.cross_attention.mlp.0.weight', 'binding_site_featurizer.cross_attention.mlp.0.bias', 'binding_site_featurizer.cross_attention.mlp.1.weight', 'binding_site_featurizer.cross_attention.mlp.1.bias', 'binding_site_featurizer.cross_attention.mlp.1.running_mean', 'binding_site_featurizer.cross_attention.mlp.1.running_var', 'binding_site_featurizer.cross_attention.mlp.1.num_batches_tracked', 'binding_site_featurizer.cross_attention.mlp.4.weight', 'binding_site_featurizer.cross_attention.mlp.4.bias', 'binding_site_featurizer.cross_attention.mlp.5.weight', 'binding_site_featurizer.cross_attention.mlp.5.bias', 'binding_site_featurizer.cross_attention.mlp.5.running_mean', 'binding_site_featurizer.cross_attention.mlp.5.running_var', 'binding_site_featurizer.cross_attention.mlp.5.num_batches_tracked', 'binding_site_featurizer.cross_attention.mlp.8.weight', 'binding_site_featurizer.cross_attention.mlp.8.bias']
# Fold 3: 100%|██████████| 4/4 [00:34<00:00,  8.65s/it]
# Original eval: 100%|██████████| 77/77 [00:01<00:00, 76.86it/s]
# Unique ligands in fold 3: 38
#   Swap repetition 1/5 done.
#   Swap repetition 2/5 done.
#   Swap repetition 3/5 done.
#   Swap repetition 4/5 done.
#   Swap repetition 5/5 done.
# Fold 3 done. Entries: 77
#
# ============================================================
# Processing fold 4 (PDB Decoys — Ligand Swap)
# ============================================================
# Global seed set to 42
# Not loaded: ['smol_binding_featurizer.0.weight', 'smol_binding_featurizer.0.bias', 'smol_binding_featurizer.1.weight', 'smol_binding_featurizer.1.bias', 'smol_binding_featurizer.1.running_mean', 'smol_binding_featurizer.1.running_var', 'smol_binding_featurizer.1.num_batches_tracked', 'binding_site_featurizer.cross_attention.smol_projection.weight', 'binding_site_featurizer.cross_attention.smol_projection.bias', 'binding_site_featurizer.cross_attention.projection.weight', 'binding_site_featurizer.cross_attention.projection.bias', 'binding_site_featurizer.cross_attention.batch_norm_projection.weight', 'binding_site_featurizer.cross_attention.batch_norm_projection.bias', 'binding_site_featurizer.cross_attention.batch_norm_projection.running_mean', 'binding_site_featurizer.cross_attention.batch_norm_projection.running_var', 'binding_site_featurizer.cross_attention.batch_norm_projection.num_batches_tracked', 'binding_site_featurizer.cross_attention.self_attention.0.0.in_proj_weight', 'binding_site_featurizer.cross_attention.self_attention.0.0.in_proj_bias', 'binding_site_featurizer.cross_attention.self_attention.0.0.out_proj.weight', 'binding_site_featurizer.cross_attention.self_attention.0.0.out_proj.bias', 'binding_site_featurizer.cross_attention.self_attention.0.1.weight', 'binding_site_featurizer.cross_attention.self_attention.0.1.bias', 'binding_site_featurizer.cross_attention.mlp.0.weight', 'binding_site_featurizer.cross_attention.mlp.0.bias', 'binding_site_featurizer.cross_attention.mlp.1.weight', 'binding_site_featurizer.cross_attention.mlp.1.bias', 'binding_site_featurizer.cross_attention.mlp.1.running_mean', 'binding_site_featurizer.cross_attention.mlp.1.running_var', 'binding_site_featurizer.cross_attention.mlp.1.num_batches_tracked', 'binding_site_featurizer.cross_attention.mlp.4.weight', 'binding_site_featurizer.cross_attention.mlp.4.bias', 'binding_site_featurizer.cross_attention.mlp.5.weight', 'binding_site_featurizer.cross_attention.mlp.5.bias', 'binding_site_featurizer.cross_attention.mlp.5.running_mean', 'binding_site_featurizer.cross_attention.mlp.5.running_var', 'binding_site_featurizer.cross_attention.mlp.5.num_batches_tracked', 'binding_site_featurizer.cross_attention.mlp.8.weight', 'binding_site_featurizer.cross_attention.mlp.8.bias']
# Fold 4: 100%|██████████| 4/4 [00:42<00:00, 10.56s/it]
# Original eval: 100%|██████████| 77/77 [00:02<00:00, 38.09it/s]
# Unique ligands in fold 4: 41
#   Swap repetition 1/5 done.
#   Swap repetition 2/5 done.
#   Swap repetition 3/5 done.
#   Swap repetition 4/5 done.
#   Swap repetition 5/5 done.
# Fold 4 done. Entries: 77
#
# ============================================================
# Processing fold 5 (PDB Decoys — Ligand Swap)
# ============================================================
# Global seed set to 42
# Not loaded: ['smol_binding_featurizer.0.weight', 'smol_binding_featurizer.0.bias', 'smol_binding_featurizer.1.weight', 'smol_binding_featurizer.1.bias', 'smol_binding_featurizer.1.running_mean', 'smol_binding_featurizer.1.running_var', 'smol_binding_featurizer.1.num_batches_tracked', 'binding_site_featurizer.cross_attention.smol_projection.weight', 'binding_site_featurizer.cross_attention.smol_projection.bias', 'binding_site_featurizer.cross_attention.projection.weight', 'binding_site_featurizer.cross_attention.projection.bias', 'binding_site_featurizer.cross_attention.batch_norm_projection.weight', 'binding_site_featurizer.cross_attention.batch_norm_projection.bias', 'binding_site_featurizer.cross_attention.batch_norm_projection.running_mean', 'binding_site_featurizer.cross_attention.batch_norm_projection.running_var', 'binding_site_featurizer.cross_attention.batch_norm_projection.num_batches_tracked', 'binding_site_featurizer.cross_attention.self_attention.0.0.in_proj_weight', 'binding_site_featurizer.cross_attention.self_attention.0.0.in_proj_bias', 'binding_site_featurizer.cross_attention.self_attention.0.0.out_proj.weight', 'binding_site_featurizer.cross_attention.self_attention.0.0.out_proj.bias', 'binding_site_featurizer.cross_attention.self_attention.0.1.weight', 'binding_site_featurizer.cross_attention.self_attention.0.1.bias', 'binding_site_featurizer.cross_attention.mlp.0.weight', 'binding_site_featurizer.cross_attention.mlp.0.bias', 'binding_site_featurizer.cross_attention.mlp.1.weight', 'binding_site_featurizer.cross_attention.mlp.1.bias', 'binding_site_featurizer.cross_attention.mlp.1.running_mean', 'binding_site_featurizer.cross_attention.mlp.1.running_var', 'binding_site_featurizer.cross_attention.mlp.1.num_batches_tracked', 'binding_site_featurizer.cross_attention.mlp.4.weight', 'binding_site_featurizer.cross_attention.mlp.4.bias', 'binding_site_featurizer.cross_attention.mlp.5.weight', 'binding_site_featurizer.cross_attention.mlp.5.bias', 'binding_site_featurizer.cross_attention.mlp.5.running_mean', 'binding_site_featurizer.cross_attention.mlp.5.running_var', 'binding_site_featurizer.cross_attention.mlp.5.num_batches_tracked', 'binding_site_featurizer.cross_attention.mlp.8.weight', 'binding_site_featurizer.cross_attention.mlp.8.bias']
# Fold 5: 100%|██████████| 4/4 [00:42<00:00, 10.72s/it]
# Original eval: 100%|██████████| 76/76 [00:00<00:00, 123.59it/s]
# Unique ligands in fold 5: 39
#   Swap repetition 1/5 done.
#   Swap repetition 2/5 done.
#   Swap repetition 3/5 done.
#   Swap repetition 4/5 done.
#   Swap repetition 5/5 done.
# Fold 5 done. Entries: 76
#
# ============================================================
# Processing fold 6 (PDB Decoys — Ligand Swap)
# ============================================================
# Global seed set to 42
# Not loaded: ['smol_binding_featurizer.0.weight', 'smol_binding_featurizer.0.bias', 'smol_binding_featurizer.1.weight', 'smol_binding_featurizer.1.bias', 'smol_binding_featurizer.1.running_mean', 'smol_binding_featurizer.1.running_var', 'smol_binding_featurizer.1.num_batches_tracked', 'binding_site_featurizer.cross_attention.smol_projection.weight', 'binding_site_featurizer.cross_attention.smol_projection.bias', 'binding_site_featurizer.cross_attention.projection.weight', 'binding_site_featurizer.cross_attention.projection.bias', 'binding_site_featurizer.cross_attention.batch_norm_projection.weight', 'binding_site_featurizer.cross_attention.batch_norm_projection.bias', 'binding_site_featurizer.cross_attention.batch_norm_projection.running_mean', 'binding_site_featurizer.cross_attention.batch_norm_projection.running_var', 'binding_site_featurizer.cross_attention.batch_norm_projection.num_batches_tracked', 'binding_site_featurizer.cross_attention.self_attention.0.0.in_proj_weight', 'binding_site_featurizer.cross_attention.self_attention.0.0.in_proj_bias', 'binding_site_featurizer.cross_attention.self_attention.0.0.out_proj.weight', 'binding_site_featurizer.cross_attention.self_attention.0.0.out_proj.bias', 'binding_site_featurizer.cross_attention.self_attention.0.1.weight', 'binding_site_featurizer.cross_attention.self_attention.0.1.bias', 'binding_site_featurizer.cross_attention.mlp.0.weight', 'binding_site_featurizer.cross_attention.mlp.0.bias', 'binding_site_featurizer.cross_attention.mlp.1.weight', 'binding_site_featurizer.cross_attention.mlp.1.bias', 'binding_site_featurizer.cross_attention.mlp.1.running_mean', 'binding_site_featurizer.cross_attention.mlp.1.running_var', 'binding_site_featurizer.cross_attention.mlp.1.num_batches_tracked', 'binding_site_featurizer.cross_attention.mlp.4.weight', 'binding_site_featurizer.cross_attention.mlp.4.bias', 'binding_site_featurizer.cross_attention.mlp.5.weight', 'binding_site_featurizer.cross_attention.mlp.5.bias', 'binding_site_featurizer.cross_attention.mlp.5.running_mean', 'binding_site_featurizer.cross_attention.mlp.5.running_var', 'binding_site_featurizer.cross_attention.mlp.5.num_batches_tracked', 'binding_site_featurizer.cross_attention.mlp.8.weight', 'binding_site_featurizer.cross_attention.mlp.8.bias']
# Fold 6: 100%|██████████| 4/4 [01:41<00:00, 25.45s/it]
# Original eval: 100%|██████████| 77/77 [00:00<00:00, 83.55it/s]
# Unique ligands in fold 6: 35
#   Swap repetition 1/5 done.
#   Swap repetition 2/5 done.
#   Swap repetition 3/5 done.
#   Swap repetition 4/5 done.
#   Swap repetition 5/5 done.
# Fold 6 done. Entries: 77
#
# ============================================================
# Processing fold 7 (PDB Decoys — Ligand Swap)
# ============================================================
# Global seed set to 42
# Not loaded: ['smol_binding_featurizer.0.weight', 'smol_binding_featurizer.0.bias', 'smol_binding_featurizer.1.weight', 'smol_binding_featurizer.1.bias', 'smol_binding_featurizer.1.running_mean', 'smol_binding_featurizer.1.running_var', 'smol_binding_featurizer.1.num_batches_tracked', 'binding_site_featurizer.cross_attention.smol_projection.weight', 'binding_site_featurizer.cross_attention.smol_projection.bias', 'binding_site_featurizer.cross_attention.projection.weight', 'binding_site_featurizer.cross_attention.projection.bias', 'binding_site_featurizer.cross_attention.batch_norm_projection.weight', 'binding_site_featurizer.cross_attention.batch_norm_projection.bias', 'binding_site_featurizer.cross_attention.batch_norm_projection.running_mean', 'binding_site_featurizer.cross_attention.batch_norm_projection.running_var', 'binding_site_featurizer.cross_attention.batch_norm_projection.num_batches_tracked', 'binding_site_featurizer.cross_attention.self_attention.0.0.in_proj_weight', 'binding_site_featurizer.cross_attention.self_attention.0.0.in_proj_bias', 'binding_site_featurizer.cross_attention.self_attention.0.0.out_proj.weight', 'binding_site_featurizer.cross_attention.self_attention.0.0.out_proj.bias', 'binding_site_featurizer.cross_attention.self_attention.0.1.weight', 'binding_site_featurizer.cross_attention.self_attention.0.1.bias', 'binding_site_featurizer.cross_attention.mlp.0.weight', 'binding_site_featurizer.cross_attention.mlp.0.bias', 'binding_site_featurizer.cross_attention.mlp.1.weight', 'binding_site_featurizer.cross_attention.mlp.1.bias', 'binding_site_featurizer.cross_attention.mlp.1.running_mean', 'binding_site_featurizer.cross_attention.mlp.1.running_var', 'binding_site_featurizer.cross_attention.mlp.1.num_batches_tracked', 'binding_site_featurizer.cross_attention.mlp.4.weight', 'binding_site_featurizer.cross_attention.mlp.4.bias', 'binding_site_featurizer.cross_attention.mlp.5.weight', 'binding_site_featurizer.cross_attention.mlp.5.bias', 'binding_site_featurizer.cross_attention.mlp.5.running_mean', 'binding_site_featurizer.cross_attention.mlp.5.running_var', 'binding_site_featurizer.cross_attention.mlp.5.num_batches_tracked', 'binding_site_featurizer.cross_attention.mlp.8.weight', 'binding_site_featurizer.cross_attention.mlp.8.bias']
# Fold 7: 100%|██████████| 4/4 [00:48<00:00, 12.24s/it]
# Original eval: 100%|██████████| 77/77 [00:01<00:00, 56.05it/s]
# Unique ligands in fold 7: 38
#   Swap repetition 1/5 done.
#   Swap repetition 2/5 done.
#   Swap repetition 3/5 done.
#   Swap repetition 4/5 done.
#   Swap repetition 5/5 done.
# Fold 7 done. Entries: 77
#
# ============================================================
# Processing fold 8 (PDB Decoys — Ligand Swap)
# ============================================================
# Global seed set to 42
# Not loaded: ['smol_binding_featurizer.0.weight', 'smol_binding_featurizer.0.bias', 'smol_binding_featurizer.1.weight', 'smol_binding_featurizer.1.bias', 'smol_binding_featurizer.1.running_mean', 'smol_binding_featurizer.1.running_var', 'smol_binding_featurizer.1.num_batches_tracked', 'binding_site_featurizer.cross_attention.smol_projection.weight', 'binding_site_featurizer.cross_attention.smol_projection.bias', 'binding_site_featurizer.cross_attention.projection.weight', 'binding_site_featurizer.cross_attention.projection.bias', 'binding_site_featurizer.cross_attention.batch_norm_projection.weight', 'binding_site_featurizer.cross_attention.batch_norm_projection.bias', 'binding_site_featurizer.cross_attention.batch_norm_projection.running_mean', 'binding_site_featurizer.cross_attention.batch_norm_projection.running_var', 'binding_site_featurizer.cross_attention.batch_norm_projection.num_batches_tracked', 'binding_site_featurizer.cross_attention.self_attention.0.0.in_proj_weight', 'binding_site_featurizer.cross_attention.self_attention.0.0.in_proj_bias', 'binding_site_featurizer.cross_attention.self_attention.0.0.out_proj.weight', 'binding_site_featurizer.cross_attention.self_attention.0.0.out_proj.bias', 'binding_site_featurizer.cross_attention.self_attention.0.1.weight', 'binding_site_featurizer.cross_attention.self_attention.0.1.bias', 'binding_site_featurizer.cross_attention.mlp.0.weight', 'binding_site_featurizer.cross_attention.mlp.0.bias', 'binding_site_featurizer.cross_attention.mlp.1.weight', 'binding_site_featurizer.cross_attention.mlp.1.bias', 'binding_site_featurizer.cross_attention.mlp.1.running_mean', 'binding_site_featurizer.cross_attention.mlp.1.running_var', 'binding_site_featurizer.cross_attention.mlp.1.num_batches_tracked', 'binding_site_featurizer.cross_attention.mlp.4.weight', 'binding_site_featurizer.cross_attention.mlp.4.bias', 'binding_site_featurizer.cross_attention.mlp.5.weight', 'binding_site_featurizer.cross_attention.mlp.5.bias', 'binding_site_featurizer.cross_attention.mlp.5.running_mean', 'binding_site_featurizer.cross_attention.mlp.5.running_var', 'binding_site_featurizer.cross_attention.mlp.5.num_batches_tracked', 'binding_site_featurizer.cross_attention.mlp.8.weight', 'binding_site_featurizer.cross_attention.mlp.8.bias']
# Fold 8: 100%|██████████| 4/4 [00:50<00:00, 12.71s/it]
# Original eval: 100%|██████████| 77/77 [00:01<00:00, 65.26it/s]
# Unique ligands in fold 8: 31
#   Swap repetition 1/5 done.
#   Swap repetition 2/5 done.
#   Swap repetition 3/5 done.
#   Swap repetition 4/5 done.
#   Swap repetition 5/5 done.
# Fold 8 done. Entries: 77
#
# ============================================================
# Processing fold 9 (PDB Decoys — Ligand Swap)
# ============================================================
# Global seed set to 42
# Not loaded: ['smol_binding_featurizer.0.weight', 'smol_binding_featurizer.0.bias', 'smol_binding_featurizer.1.weight', 'smol_binding_featurizer.1.bias', 'smol_binding_featurizer.1.running_mean', 'smol_binding_featurizer.1.running_var', 'smol_binding_featurizer.1.num_batches_tracked', 'binding_site_featurizer.cross_attention.smol_projection.weight', 'binding_site_featurizer.cross_attention.smol_projection.bias', 'binding_site_featurizer.cross_attention.projection.weight', 'binding_site_featurizer.cross_attention.projection.bias', 'binding_site_featurizer.cross_attention.batch_norm_projection.weight', 'binding_site_featurizer.cross_attention.batch_norm_projection.bias', 'binding_site_featurizer.cross_attention.batch_norm_projection.running_mean', 'binding_site_featurizer.cross_attention.batch_norm_projection.running_var', 'binding_site_featurizer.cross_attention.batch_norm_projection.num_batches_tracked', 'binding_site_featurizer.cross_attention.self_attention.0.0.in_proj_weight', 'binding_site_featurizer.cross_attention.self_attention.0.0.in_proj_bias', 'binding_site_featurizer.cross_attention.self_attention.0.0.out_proj.weight', 'binding_site_featurizer.cross_attention.self_attention.0.0.out_proj.bias', 'binding_site_featurizer.cross_attention.self_attention.0.1.weight', 'binding_site_featurizer.cross_attention.self_attention.0.1.bias', 'binding_site_featurizer.cross_attention.mlp.0.weight', 'binding_site_featurizer.cross_attention.mlp.0.bias', 'binding_site_featurizer.cross_attention.mlp.1.weight', 'binding_site_featurizer.cross_attention.mlp.1.bias', 'binding_site_featurizer.cross_attention.mlp.1.running_mean', 'binding_site_featurizer.cross_attention.mlp.1.running_var', 'binding_site_featurizer.cross_attention.mlp.1.num_batches_tracked', 'binding_site_featurizer.cross_attention.mlp.4.weight', 'binding_site_featurizer.cross_attention.mlp.4.bias', 'binding_site_featurizer.cross_attention.mlp.5.weight', 'binding_site_featurizer.cross_attention.mlp.5.bias', 'binding_site_featurizer.cross_attention.mlp.5.running_mean', 'binding_site_featurizer.cross_attention.mlp.5.running_var', 'binding_site_featurizer.cross_attention.mlp.5.num_batches_tracked', 'binding_site_featurizer.cross_attention.mlp.8.weight', 'binding_site_featurizer.cross_attention.mlp.8.bias']
# Fold 9: 100%|██████████| 4/4 [01:00<00:00, 15.01s/it]
# Original eval: 100%|██████████| 77/77 [00:00<00:00, 83.26it/s]
# Unique ligands in fold 9: 38
#   Swap repetition 1/5 done.
#   Swap repetition 2/5 done.
#   Swap repetition 3/5 done.
#   Swap repetition 4/5 done.
#   Swap repetition 5/5 done.
# Fold 9 done. Entries: 77
#
# ============================================================
# Processing fold 10 (PDB Decoys — Ligand Swap)
# ============================================================
# Global seed set to 42
# Not loaded: ['smol_binding_featurizer.0.weight', 'smol_binding_featurizer.0.bias', 'smol_binding_featurizer.1.weight', 'smol_binding_featurizer.1.bias', 'smol_binding_featurizer.1.running_mean', 'smol_binding_featurizer.1.running_var', 'smol_binding_featurizer.1.num_batches_tracked', 'binding_site_featurizer.cross_attention.smol_projection.weight', 'binding_site_featurizer.cross_attention.smol_projection.bias', 'binding_site_featurizer.cross_attention.projection.weight', 'binding_site_featurizer.cross_attention.projection.bias', 'binding_site_featurizer.cross_attention.batch_norm_projection.weight', 'binding_site_featurizer.cross_attention.batch_norm_projection.bias', 'binding_site_featurizer.cross_attention.batch_norm_projection.running_mean', 'binding_site_featurizer.cross_attention.batch_norm_projection.running_var', 'binding_site_featurizer.cross_attention.batch_norm_projection.num_batches_tracked', 'binding_site_featurizer.cross_attention.self_attention.0.0.in_proj_weight', 'binding_site_featurizer.cross_attention.self_attention.0.0.in_proj_bias', 'binding_site_featurizer.cross_attention.self_attention.0.0.out_proj.weight', 'binding_site_featurizer.cross_attention.self_attention.0.0.out_proj.bias', 'binding_site_featurizer.cross_attention.self_attention.0.1.weight', 'binding_site_featurizer.cross_attention.self_attention.0.1.bias', 'binding_site_featurizer.cross_attention.mlp.0.weight', 'binding_site_featurizer.cross_attention.mlp.0.bias', 'binding_site_featurizer.cross_attention.mlp.1.weight', 'binding_site_featurizer.cross_attention.mlp.1.bias', 'binding_site_featurizer.cross_attention.mlp.1.running_mean', 'binding_site_featurizer.cross_attention.mlp.1.running_var', 'binding_site_featurizer.cross_attention.mlp.1.num_batches_tracked', 'binding_site_featurizer.cross_attention.mlp.4.weight', 'binding_site_featurizer.cross_attention.mlp.4.bias', 'binding_site_featurizer.cross_attention.mlp.5.weight', 'binding_site_featurizer.cross_attention.mlp.5.bias', 'binding_site_featurizer.cross_attention.mlp.5.running_mean', 'binding_site_featurizer.cross_attention.mlp.5.running_var', 'binding_site_featurizer.cross_attention.mlp.5.num_batches_tracked', 'binding_site_featurizer.cross_attention.mlp.8.weight', 'binding_site_featurizer.cross_attention.mlp.8.bias']
# Fold 10: 100%|██████████| 4/4 [01:15<00:00, 18.88s/it]
# Original eval: 100%|██████████| 77/77 [00:02<00:00, 37.67it/s]
# Unique ligands in fold 10: 54
#   Swap repetition 1/5 done.
#   Swap repetition 2/5 done.
#   Swap repetition 3/5 done.
#   Swap repetition 4/5 done.
#   Swap repetition 5/5 done.
# Fold 10 done. Entries: 77

# %% [markdown]
# ### PDB Decoys — Target-level (Local) AuROC

# %%
# ============================================================
# PDB Decoys — Target-level (Local) AuROC Ligand Swap Analysis
# ============================================================

print('\n' + '='*70)
print('TARGET-LEVEL (LOCAL) AuROC LIGAND SWAP — PDB Decoys')
print('='*70)

all_local_auc_original = []
all_local_auc_swapped_per_k = [[] for _ in range(K_SWAP_REPETITIONS)]
all_local_rp_original = []
all_local_rp_swapped_per_k = [[] for _ in range(K_SWAP_REPETITIONS)]

for fold_num in range(1, 11):
    res = all_fold_results_pdb[fold_num]
    rna_names = res['rna_names']
    
    # --- Original: group by rna_name ---
    target_aurocs_orig = defaultdict(list)
    target_rps_orig = defaultdict(list)
    for i, rn in enumerate(rna_names):
        target_rps_orig[rn].append(res['original_rank_percentiles'][i])
        target_aurocs_orig[rn].append(res['original_pair_aurocs'][i])
    
    valid_target_aurocs_orig = [np.mean(aurocs) for aurocs in target_aurocs_orig.values()]
    fold_local_auc_orig = np.mean(valid_target_aurocs_orig)
    fold_local_rp_orig = np.mean([np.mean(rps) for rps in target_rps_orig.values()])
    all_local_auc_original.append(fold_local_auc_orig)
    all_local_rp_original.append(fold_local_rp_orig)
    
    # --- Swapped: for each repetition k ---
    for k in range(K_SWAP_REPETITIONS):
        swap_res = res['swap_rep_results'][k]
        target_aurocs_swap = defaultdict(list)
        target_rps_swap = defaultdict(list)
        
        for i, rn in enumerate(rna_names):  # group by ORIGINAL rna_name
            target_aurocs_swap[rn].append(swap_res['pair_aurocs'][i])
            target_rps_swap[rn].append(swap_res['rank_percentiles'][i])
        
        valid_target_aurocs_swap = [np.mean(aurocs) for aurocs in target_aurocs_swap.values()]
        all_local_auc_swapped_per_k[k].append(np.mean(valid_target_aurocs_swap))
        all_local_rp_swapped_per_k[k].append(np.mean([np.mean(rps) for rps in target_rps_swap.values()]))
    
    print(f'Fold {fold_num}: Local AuROC original = {fold_local_auc_orig:.4f}')

# Aggregate across folds
local_auc_original = np.mean(all_local_auc_original)
local_auc_original_std = np.std(all_local_auc_original, ddof=1)
local_rp_original = np.mean(all_local_rp_original)
local_rp_original_std = np.std(all_local_rp_original, ddof=1)

# Flat per-pair stats for reference
all_pair_aurocs_flat = []
all_pair_rps_flat = []
for fold_num in range(1, 11):
    res = all_fold_results_pdb[fold_num]
    all_pair_aurocs_flat.extend(res['original_pair_aurocs'])
    all_pair_rps_flat.extend(res['original_rank_percentiles'])
flat_auc_mean = np.mean(all_pair_aurocs_flat)
flat_auc_std = np.std(all_pair_aurocs_flat, ddof=1)
flat_rp_mean = np.mean(all_pair_rps_flat)
flat_rp_std = np.std(all_pair_rps_flat, ddof=1)

# For each k, compute mean across folds, then take mean/std across K
local_auc_swapped_per_k = [np.mean(all_local_auc_swapped_per_k[k]) for k in range(K_SWAP_REPETITIONS)]
local_rp_swapped_per_k = [np.mean(all_local_rp_swapped_per_k[k]) for k in range(K_SWAP_REPETITIONS)]

local_auc_swapped_mean = np.mean(local_auc_swapped_per_k)
local_auc_swapped_std = np.std(local_auc_swapped_per_k, ddof=1)
local_rp_swapped_mean = np.mean(local_rp_swapped_per_k)
local_rp_swapped_std = np.std(local_rp_swapped_per_k, ddof=1)

# Per-k performance gap, then mean ± std
gap_local_auc_per_k = [100 * (local_auc_swapped_per_k[k] - local_auc_original) / local_auc_original for k in range(K_SWAP_REPETITIONS)]
gap_local_rp_per_k = [100 * (local_rp_swapped_per_k[k] - local_rp_original) / local_rp_original for k in range(K_SWAP_REPETITIONS)]
gap_local_auc_mean = np.mean(gap_local_auc_per_k)
gap_local_auc_std = np.std(gap_local_auc_per_k, ddof=1)
gap_local_rp_mean = np.mean(gap_local_rp_per_k)
gap_local_rp_std = np.std(gap_local_rp_per_k, ddof=1)

print(f'\n=== Target-level (Local) Results — PDB Decoys (Ligand Swap) ===')
print(f'Original  Local AuROC: {local_auc_original:.4f} ± {local_auc_original_std:.4f} (across 10 folds)')
print(f'Swapped   Local AuROC: {local_auc_swapped_mean:.4f} ± {local_auc_swapped_std:.4f} (K={K_SWAP_REPETITIONS})')
print(f'Performance Gap:       {gap_local_auc_mean:.2f}% ± {gap_local_auc_std:.2f}%')
print(f'\nOriginal  Local Rank Percentile: {local_rp_original:.4f} ± {local_rp_original_std:.4f} (across 10 folds)')
print(f'Swapped   Local Rank Percentile: {local_rp_swapped_mean:.4f} ± {local_rp_swapped_std:.4f}')
print(f'Performance Gap:                 {gap_local_rp_mean:.2f}% ± {gap_local_rp_std:.2f}%')
print(f'\n--- Flat per-pair stats (for reference) ---')
print(f'Total pairs: {len(all_pair_aurocs_flat)}')
print(f'Flat Mean Rank Percentile: {flat_rp_mean:.4f} ± {flat_rp_std:.4f}')
print(f'Flat Mean Per-pair AUROC:  {flat_auc_mean:.4f} ± {flat_auc_std:.4f}')
# Out:
# ======================================================================
# TARGET-LEVEL (LOCAL) AuROC LIGAND SWAP — PDB Decoys
# ======================================================================
# Fold 1: Local AuROC original = 0.8546
# Fold 2: Local AuROC original = 0.8211
# Fold 3: Local AuROC original = 0.8453
# Fold 4: Local AuROC original = 0.8098
# Fold 5: Local AuROC original = 0.8399
# Fold 6: Local AuROC original = 0.8708
# Fold 7: Local AuROC original = 0.8823
# Fold 8: Local AuROC original = 0.7457
# Fold 9: Local AuROC original = 0.7948
# Fold 10: Local AuROC original = 0.7744
#
# === Target-level (Local) Results — PDB Decoys (Ligand Swap) ===
# Original  Local AuROC: 0.8239 ± 0.0433 (across 10 folds)
# Swapped   Local AuROC: 0.5046 ± 0.0132 (K=5)
# Performance Gap:       -38.75% ± 1.60%
#
# Original  Local Rank Percentile: 0.8274 ± 0.0417 (across 10 folds)
# Swapped   Local Rank Percentile: 0.5122 ± 0.0126
# Performance Gap:                 -38.09% ± 1.53%
#
# --- Flat per-pair stats (for reference) ---
# Total pairs: 765
# Flat Mean Rank Percentile: 0.8256 ± 0.2256
# Flat Mean Per-pair AUROC:  0.8220 ± 0.2319

# %% [markdown]
# ### PDB Decoys — Global AuROC

# %%
# ============================================================
# PDB Decoys — Global AuROC Ligand Swap Analysis
# ============================================================

print('\n' + '='*70)
print('GLOBAL AuROC LIGAND SWAP — PDB Decoys')
print('='*70)

all_global_auc_original = []
all_global_auc_swapped_per_k = [[] for _ in range(K_SWAP_REPETITIONS)]

for fold_num in range(1, 11):
    res = all_fold_results_pdb[fold_num]
    
    # --- Original: flatten all scores and labels ---
    all_labels = []
    all_scores = []
    for match_score, decoy_scores in res['original_scores']:
        all_scores.append(match_score)
        all_labels.append(1)
        for ds in decoy_scores:
            all_scores.append(ds)
            all_labels.append(0)
    
    all_scores_norm = normalize_scores(all_scores)
    fold_global_auc_orig = roc_auc_score(all_labels, all_scores_norm)
    all_global_auc_original.append(fold_global_auc_orig)
    
    # --- Swapped: for each repetition k ---
    for k in range(K_SWAP_REPETITIONS):
        swap_res = res['swap_rep_results'][k]
        all_labels_s = []
        all_scores_s = []
        for match_score, decoy_scores in swap_res['scores']:
            all_scores_s.append(match_score)
            all_labels_s.append(1)
            for ds in decoy_scores:
                all_scores_s.append(ds)
                all_labels_s.append(0)
        
        all_scores_s_norm = normalize_scores(all_scores_s)
        fold_global_auc_swap = roc_auc_score(all_labels_s, all_scores_s_norm)
        all_global_auc_swapped_per_k[k].append(fold_global_auc_swap)
    
    print(f'Fold {fold_num}: Global AuROC original = {fold_global_auc_orig:.4f}')

# Aggregate
global_auc_original = np.mean(all_global_auc_original)
global_auc_swapped_per_k = [np.mean(all_global_auc_swapped_per_k[k]) for k in range(K_SWAP_REPETITIONS)]
global_auc_swapped_mean = np.mean(global_auc_swapped_per_k)
global_auc_swapped_std = np.std(global_auc_swapped_per_k, ddof=1)

# Per-k performance gap
gap_global_auc_per_k = [100 * (global_auc_swapped_per_k[k] - global_auc_original) / global_auc_original for k in range(K_SWAP_REPETITIONS)]
gap_global_auc_mean = np.mean(gap_global_auc_per_k)
gap_global_auc_std = np.std(gap_global_auc_per_k, ddof=1)

print(f'\n=== Global Results — PDB Decoys (Ligand Swap) ===')
print(f'Original  Global AuROC: {global_auc_original:.4f}')
print(f'Swapped   Global AuROC: {global_auc_swapped_mean:.4f} ± {global_auc_swapped_std:.4f} (K={K_SWAP_REPETITIONS})')
print(f'Performance Gap:        {gap_global_auc_mean:.2f}% ± {gap_global_auc_std:.2f}%')
# Out:
# ======================================================================
# GLOBAL AuROC LIGAND SWAP — PDB Decoys
# ======================================================================
# Fold 1: Global AuROC original = 0.8299
# Fold 2: Global AuROC original = 0.8260
# Fold 3: Global AuROC original = 0.8174
# Fold 4: Global AuROC original = 0.8021
# Fold 5: Global AuROC original = 0.8358
# Fold 6: Global AuROC original = 0.8744
# Fold 7: Global AuROC original = 0.8616
# Fold 8: Global AuROC original = 0.7808
# Fold 9: Global AuROC original = 0.7566
# Fold 10: Global AuROC original = 0.7723
#
# === Global Results — PDB Decoys (Ligand Swap) ===
# Original  Global AuROC: 0.8157
# Swapped   Global AuROC: 0.5080 ± 0.0101 (K=5)
# Performance Gap:        -37.72% ± 1.24%

# %% [markdown]
# ---
# ## DecoyFinder Decoys

# %%
# ============================================================
# DecoyFinder Decoys — Collect data + original & ligand-swapped evaluation
# ============================================================

decoy_db_path = 'data/rnamigos1_decoyfinder/clean'
all_fold_results_df = {}  # fold_num -> dict of results

for current_fold_num in range(1, 11):
    print(f'\n{"="*60}')
    print(f'Processing fold {current_fold_num} (DecoyFinder Decoys — Ligand Swap)')
    print(f'{"="*60}')
    
    val_rna_seq_list, val_match_smol_list, val_rna_name_list, val_match_smol_name_list, \
        val_binding_index_list, val_match_smol_fp_list, train_rna_seq_list, train_match_smol_list, \
        train_rna_name_list, train_match_smol_name_list, train_binding_index_list, \
        train_match_smol_fp_list, match_pair_dict = build_val_test_set(
            fold_num=current_fold_num - 1,
            dict_path=current_path,
            topk_decoy=topk_decoy)
    
    val_dataset = RLDataset(
        rna_sequences=val_rna_seq_list,
        rna_sequences_names=val_rna_name_list,
        match_smols=val_match_smol_fp_list,
        match_smols_names=val_match_smol_name_list,
        non_binding_index_list=val_binding_index_list,
        is_val=True)
    val_dataloader = RLDataLoader(
        dataset=val_dataset,
        batch_size=batch_size,
        num_workers=num_workers,
        if_shuffle=False)
    
    weight_path = f'weights/fold{current_fold_num}.pth'
    smartbind_model = load_smartbind_models(
        model_path=weight_path, device=device, vs_mode=True)
    smartbind_model.eval()
    
    fold_entries = []
    rna_emb_cache = {}
    
    with torch.no_grad():
        for batch in tqdm.tqdm(val_dataloader.dataloader, desc=f'Fold {current_fold_num}'):
            rna_sequences, match_smols, _, _, _, _ = batch
            
            for rna_seq, match_smol in zip(rna_sequences, match_smols):
                rna_name = rna_seq[0]
                rna_seq_str = rna_seq[1]
                match_smol_name = match_smol[0]
                match_smol_fp = match_smol[1]
                
                # Build DecoyFinder decoys
                decoy_fps = []
                decoy_file_path = os.path.join(decoy_db_path, f'{match_smol_name}.txt')
                if os.path.exists(decoy_file_path):
                    with open(decoy_file_path, 'r') as f:
                        for line in f:
                            smol = line.strip()
                            pf2 = convert_smiles_to_pf2(smol)
                            decoy_fps.append(pf2)
                
                if len(decoy_fps) == 0:
                    continue
                
                if rna_name not in rna_emb_cache:
                    rna_emb = smartbind_model.inference_single_rna(rna_seq_str)
                    rna_emb_cache[rna_name] = rna_emb
                
                fold_entries.append({
                    'rna_name': rna_name,
                    'rna_seq': rna_seq_str,
                    'match_smol_name': match_smol_name,
                    'match_smol_fp': match_smol_fp,
                    'decoy_fps': decoy_fps,
                })
    
    # ===== Original evaluation =====
    rna_names = []
    original_scores = []
    original_rank_percentiles = []
    original_pair_aurocs = []
    
    with torch.no_grad():
        for entry in tqdm.tqdm(fold_entries, desc='Original eval'):
            rna_emb = rna_emb_cache[entry['rna_name']]
            match_score, decoy_scores = compute_scores_for_pair(
                smartbind_model, rna_emb, entry['match_smol_fp'], entry['decoy_fps'])
            
            rna_names.append(entry['rna_name'])
            original_scores.append((match_score, decoy_scores))
            original_rank_percentiles.append(compute_rank_percentile(match_score, decoy_scores))
            original_pair_aurocs.append(compute_pair_auroc(match_score, decoy_scores))
    
    # ===== Ligand-Swapped evaluation =====
    unique_ligand_names = list(set(e['match_smol_name'] for e in fold_entries))
    ligand_fp_map = {}
    for e in fold_entries:
        if e['match_smol_name'] not in ligand_fp_map:
            ligand_fp_map[e['match_smol_name']] = e['match_smol_fp']
    
    n_ligands = len(unique_ligand_names)
    print(f'Unique ligands in fold {current_fold_num}: {n_ligands}')
    
    swap_rep_results = []
    rng = np.random.RandomState(RANDOM_SEED + current_fold_num)
    
    for k in range(K_SWAP_REPETITIONS):
        permuted_ligand_names = unique_ligand_names.copy()
        rng.shuffle(permuted_ligand_names)
        if n_ligands > 1:
            while any(permuted_ligand_names[i] == unique_ligand_names[i] for i in range(n_ligands)):
                rng.shuffle(permuted_ligand_names)
        sigma = dict(zip(unique_ligand_names, permuted_ligand_names))
        
        swapped_scores_k = []
        swapped_rank_percentiles_k = []
        swapped_pair_aurocs_k = []
        
        with torch.no_grad():
            for entry in fold_entries:
                rna_emb = rna_emb_cache[entry['rna_name']]  # original RNA
                swapped_ligand_name = sigma[entry['match_smol_name']]
                swapped_ligand_fp = ligand_fp_map[swapped_ligand_name]
                
                match_score, decoy_scores = compute_scores_for_pair(
                    smartbind_model, rna_emb,
                    swapped_ligand_fp, entry['decoy_fps'])
                
                swapped_scores_k.append((match_score, decoy_scores))
                swapped_rank_percentiles_k.append(compute_rank_percentile(match_score, decoy_scores))
                swapped_pair_aurocs_k.append(compute_pair_auroc(match_score, decoy_scores))
        
        swap_rep_results.append({
            'scores': swapped_scores_k,
            'rank_percentiles': swapped_rank_percentiles_k,
            'pair_aurocs': swapped_pair_aurocs_k,
        })
        print(f'  Swap repetition {k+1}/{K_SWAP_REPETITIONS} done.')
    
    all_fold_results_df[current_fold_num] = {
        'rna_names': rna_names,
        'original_scores': original_scores,
        'original_rank_percentiles': original_rank_percentiles,
        'original_pair_aurocs': original_pair_aurocs,
        'swap_rep_results': swap_rep_results,
        'unique_ligand_names': unique_ligand_names,
        'n_entries': len(fold_entries),
    }
    
    print(f'Fold {current_fold_num} done. Entries: {len(fold_entries)}')
# Out:
# ============================================================
# Processing fold 1 (DecoyFinder Decoys — Ligand Swap)
# ============================================================
# Global seed set to 42
# Not loaded: ['smol_binding_featurizer.0.weight', 'smol_binding_featurizer.0.bias', 'smol_binding_featurizer.1.weight', 'smol_binding_featurizer.1.bias', 'smol_binding_featurizer.1.running_mean', 'smol_binding_featurizer.1.running_var', 'smol_binding_featurizer.1.num_batches_tracked', 'binding_site_featurizer.cross_attention.smol_projection.weight', 'binding_site_featurizer.cross_attention.smol_projection.bias', 'binding_site_featurizer.cross_attention.projection.weight', 'binding_site_featurizer.cross_attention.projection.bias', 'binding_site_featurizer.cross_attention.batch_norm_projection.weight', 'binding_site_featurizer.cross_attention.batch_norm_projection.bias', 'binding_site_featurizer.cross_attention.batch_norm_projection.running_mean', 'binding_site_featurizer.cross_attention.batch_norm_projection.running_var', 'binding_site_featurizer.cross_attention.batch_norm_projection.num_batches_tracked', 'binding_site_featurizer.cross_attention.self_attention.0.0.in_proj_weight', 'binding_site_featurizer.cross_attention.self_attention.0.0.in_proj_bias', 'binding_site_featurizer.cross_attention.self_attention.0.0.out_proj.weight', 'binding_site_featurizer.cross_attention.self_attention.0.0.out_proj.bias', 'binding_site_featurizer.cross_attention.self_attention.0.1.weight', 'binding_site_featurizer.cross_attention.self_attention.0.1.bias', 'binding_site_featurizer.cross_attention.mlp.0.weight', 'binding_site_featurizer.cross_attention.mlp.0.bias', 'binding_site_featurizer.cross_attention.mlp.1.weight', 'binding_site_featurizer.cross_attention.mlp.1.bias', 'binding_site_featurizer.cross_attention.mlp.1.running_mean', 'binding_site_featurizer.cross_attention.mlp.1.running_var', 'binding_site_featurizer.cross_attention.mlp.1.num_batches_tracked', 'binding_site_featurizer.cross_attention.mlp.4.weight', 'binding_site_featurizer.cross_attention.mlp.4.bias', 'binding_site_featurizer.cross_attention.mlp.5.weight', 'binding_site_featurizer.cross_attention.mlp.5.bias', 'binding_site_featurizer.cross_attention.mlp.5.running_mean', 'binding_site_featurizer.cross_attention.mlp.5.running_var', 'binding_site_featurizer.cross_attention.mlp.5.num_batches_tracked', 'binding_site_featurizer.cross_attention.mlp.8.weight', 'binding_site_featurizer.cross_attention.mlp.8.bias']
# Fold 1: 100%|██████████| 3/3 [00:52<00:00, 17.59s/it]
# Original eval: 100%|██████████| 68/68 [00:01<00:00, 48.15it/s]
# Unique ligands in fold 1: 43
#   Swap repetition 1/5 done.
#   Swap repetition 2/5 done.
#   Swap repetition 3/5 done.
#   Swap repetition 4/5 done.
#   Swap repetition 5/5 done.
# Fold 1 done. Entries: 68
#
# ============================================================
# Processing fold 2 (DecoyFinder Decoys — Ligand Swap)
# ============================================================
# Global seed set to 42
# Not loaded: ['smol_binding_featurizer.0.weight', 'smol_binding_featurizer.0.bias', 'smol_binding_featurizer.1.weight', 'smol_binding_featurizer.1.bias', 'smol_binding_featurizer.1.running_mean', 'smol_binding_featurizer.1.running_var', 'smol_binding_featurizer.1.num_batches_tracked', 'binding_site_featurizer.cross_attention.smol_projection.weight', 'binding_site_featurizer.cross_attention.smol_projection.bias', 'binding_site_featurizer.cross_attention.projection.weight', 'binding_site_featurizer.cross_attention.projection.bias', 'binding_site_featurizer.cross_attention.batch_norm_projection.weight', 'binding_site_featurizer.cross_attention.batch_norm_projection.bias', 'binding_site_featurizer.cross_attention.batch_norm_projection.running_mean', 'binding_site_featurizer.cross_attention.batch_norm_projection.running_var', 'binding_site_featurizer.cross_attention.batch_norm_projection.num_batches_tracked', 'binding_site_featurizer.cross_attention.self_attention.0.0.in_proj_weight', 'binding_site_featurizer.cross_attention.self_attention.0.0.in_proj_bias', 'binding_site_featurizer.cross_attention.self_attention.0.0.out_proj.weight', 'binding_site_featurizer.cross_attention.self_attention.0.0.out_proj.bias', 'binding_site_featurizer.cross_attention.self_attention.0.1.weight', 'binding_site_featurizer.cross_attention.self_attention.0.1.bias', 'binding_site_featurizer.cross_attention.mlp.0.weight', 'binding_site_featurizer.cross_attention.mlp.0.bias', 'binding_site_featurizer.cross_attention.mlp.1.weight', 'binding_site_featurizer.cross_attention.mlp.1.bias', 'binding_site_featurizer.cross_attention.mlp.1.running_mean', 'binding_site_featurizer.cross_attention.mlp.1.running_var', 'binding_site_featurizer.cross_attention.mlp.1.num_batches_tracked', 'binding_site_featurizer.cross_attention.mlp.4.weight', 'binding_site_featurizer.cross_attention.mlp.4.bias', 'binding_site_featurizer.cross_attention.mlp.5.weight', 'binding_site_featurizer.cross_attention.mlp.5.bias', 'binding_site_featurizer.cross_attention.mlp.5.running_mean', 'binding_site_featurizer.cross_attention.mlp.5.running_var', 'binding_site_featurizer.cross_attention.mlp.5.num_batches_tracked', 'binding_site_featurizer.cross_attention.mlp.8.weight', 'binding_site_featurizer.cross_attention.mlp.8.bias']
# Fold 2: 100%|██████████| 4/4 [00:37<00:00,  9.41s/it]
# Original eval: 100%|██████████| 72/72 [00:00<00:00, 98.61it/s]
# Unique ligands in fold 2: 51
#   Swap repetition 1/5 done.
#   Swap repetition 2/5 done.
#   Swap repetition 3/5 done.
#   Swap repetition 4/5 done.
#   Swap repetition 5/5 done.
# Fold 2 done. Entries: 72
#
# ============================================================
# Processing fold 3 (DecoyFinder Decoys — Ligand Swap)
# ============================================================
# Global seed set to 42
# Not loaded: ['smol_binding_featurizer.0.weight', 'smol_binding_featurizer.0.bias', 'smol_binding_featurizer.1.weight', 'smol_binding_featurizer.1.bias', 'smol_binding_featurizer.1.running_mean', 'smol_binding_featurizer.1.running_var', 'smol_binding_featurizer.1.num_batches_tracked', 'binding_site_featurizer.cross_attention.smol_projection.weight', 'binding_site_featurizer.cross_attention.smol_projection.bias', 'binding_site_featurizer.cross_attention.projection.weight', 'binding_site_featurizer.cross_attention.projection.bias', 'binding_site_featurizer.cross_attention.batch_norm_projection.weight', 'binding_site_featurizer.cross_attention.batch_norm_projection.bias', 'binding_site_featurizer.cross_attention.batch_norm_projection.running_mean', 'binding_site_featurizer.cross_attention.batch_norm_projection.running_var', 'binding_site_featurizer.cross_attention.batch_norm_projection.num_batches_tracked', 'binding_site_featurizer.cross_attention.self_attention.0.0.in_proj_weight', 'binding_site_featurizer.cross_attention.self_attention.0.0.in_proj_bias', 'binding_site_featurizer.cross_attention.self_attention.0.0.out_proj.weight', 'binding_site_featurizer.cross_attention.self_attention.0.0.out_proj.bias', 'binding_site_featurizer.cross_attention.self_attention.0.1.weight', 'binding_site_featurizer.cross_attention.self_attention.0.1.bias', 'binding_site_featurizer.cross_attention.mlp.0.weight', 'binding_site_featurizer.cross_attention.mlp.0.bias', 'binding_site_featurizer.cross_attention.mlp.1.weight', 'binding_site_featurizer.cross_attention.mlp.1.bias', 'binding_site_featurizer.cross_attention.mlp.1.running_mean', 'binding_site_featurizer.cross_attention.mlp.1.running_var', 'binding_site_featurizer.cross_attention.mlp.1.num_batches_tracked', 'binding_site_featurizer.cross_attention.mlp.4.weight', 'binding_site_featurizer.cross_attention.mlp.4.bias', 'binding_site_featurizer.cross_attention.mlp.5.weight', 'binding_site_featurizer.cross_attention.mlp.5.bias', 'binding_site_featurizer.cross_attention.mlp.5.running_mean', 'binding_site_featurizer.cross_attention.mlp.5.running_var', 'binding_site_featurizer.cross_attention.mlp.5.num_batches_tracked', 'binding_site_featurizer.cross_attention.mlp.8.weight', 'binding_site_featurizer.cross_attention.mlp.8.bias']
# Fold 3: 100%|██████████| 4/4 [00:52<00:00, 13.23s/it]
# Original eval: 100%|██████████| 72/72 [00:01<00:00, 44.64it/s]
# Unique ligands in fold 3: 36
#   Swap repetition 1/5 done.
#   Swap repetition 2/5 done.
#   Swap repetition 3/5 done.
#   Swap repetition 4/5 done.
#   Swap repetition 5/5 done.
# Fold 3 done. Entries: 72
#
# ============================================================
# Processing fold 4 (DecoyFinder Decoys — Ligand Swap)
# ============================================================
# Global seed set to 42
# Not loaded: ['smol_binding_featurizer.0.weight', 'smol_binding_featurizer.0.bias', 'smol_binding_featurizer.1.weight', 'smol_binding_featurizer.1.bias', 'smol_binding_featurizer.1.running_mean', 'smol_binding_featurizer.1.running_var', 'smol_binding_featurizer.1.num_batches_tracked', 'binding_site_featurizer.cross_attention.smol_projection.weight', 'binding_site_featurizer.cross_attention.smol_projection.bias', 'binding_site_featurizer.cross_attention.projection.weight', 'binding_site_featurizer.cross_attention.projection.bias', 'binding_site_featurizer.cross_attention.batch_norm_projection.weight', 'binding_site_featurizer.cross_attention.batch_norm_projection.bias', 'binding_site_featurizer.cross_attention.batch_norm_projection.running_mean', 'binding_site_featurizer.cross_attention.batch_norm_projection.running_var', 'binding_site_featurizer.cross_attention.batch_norm_projection.num_batches_tracked', 'binding_site_featurizer.cross_attention.self_attention.0.0.in_proj_weight', 'binding_site_featurizer.cross_attention.self_attention.0.0.in_proj_bias', 'binding_site_featurizer.cross_attention.self_attention.0.0.out_proj.weight', 'binding_site_featurizer.cross_attention.self_attention.0.0.out_proj.bias', 'binding_site_featurizer.cross_attention.self_attention.0.1.weight', 'binding_site_featurizer.cross_attention.self_attention.0.1.bias', 'binding_site_featurizer.cross_attention.mlp.0.weight', 'binding_site_featurizer.cross_attention.mlp.0.bias', 'binding_site_featurizer.cross_attention.mlp.1.weight', 'binding_site_featurizer.cross_attention.mlp.1.bias', 'binding_site_featurizer.cross_attention.mlp.1.running_mean', 'binding_site_featurizer.cross_attention.mlp.1.running_var', 'binding_site_featurizer.cross_attention.mlp.1.num_batches_tracked', 'binding_site_featurizer.cross_attention.mlp.4.weight', 'binding_site_featurizer.cross_attention.mlp.4.bias', 'binding_site_featurizer.cross_attention.mlp.5.weight', 'binding_site_featurizer.cross_attention.mlp.5.bias', 'binding_site_featurizer.cross_attention.mlp.5.running_mean', 'binding_site_featurizer.cross_attention.mlp.5.running_var', 'binding_site_featurizer.cross_attention.mlp.5.num_batches_tracked', 'binding_site_featurizer.cross_attention.mlp.8.weight', 'binding_site_featurizer.cross_attention.mlp.8.bias']
# Fold 4: 100%|██████████| 4/4 [00:49<00:00, 12.30s/it]
# Original eval: 100%|██████████| 68/68 [00:00<00:00, 75.83it/s]
# Unique ligands in fold 4: 35
#   Swap repetition 1/5 done.
#   Swap repetition 2/5 done.
#   Swap repetition 3/5 done.
#   Swap repetition 4/5 done.
#   Swap repetition 5/5 done.
# Fold 4 done. Entries: 68
#
# ============================================================
# Processing fold 5 (DecoyFinder Decoys — Ligand Swap)
# ============================================================
# Global seed set to 42
# Not loaded: ['smol_binding_featurizer.0.weight', 'smol_binding_featurizer.0.bias', 'smol_binding_featurizer.1.weight', 'smol_binding_featurizer.1.bias', 'smol_binding_featurizer.1.running_mean', 'smol_binding_featurizer.1.running_var', 'smol_binding_featurizer.1.num_batches_tracked', 'binding_site_featurizer.cross_attention.smol_projection.weight', 'binding_site_featurizer.cross_attention.smol_projection.bias', 'binding_site_featurizer.cross_attention.projection.weight', 'binding_site_featurizer.cross_attention.projection.bias', 'binding_site_featurizer.cross_attention.batch_norm_projection.weight', 'binding_site_featurizer.cross_attention.batch_norm_projection.bias', 'binding_site_featurizer.cross_attention.batch_norm_projection.running_mean', 'binding_site_featurizer.cross_attention.batch_norm_projection.running_var', 'binding_site_featurizer.cross_attention.batch_norm_projection.num_batches_tracked', 'binding_site_featurizer.cross_attention.self_attention.0.0.in_proj_weight', 'binding_site_featurizer.cross_attention.self_attention.0.0.in_proj_bias', 'binding_site_featurizer.cross_attention.self_attention.0.0.out_proj.weight', 'binding_site_featurizer.cross_attention.self_attention.0.0.out_proj.bias', 'binding_site_featurizer.cross_attention.self_attention.0.1.weight', 'binding_site_featurizer.cross_attention.self_attention.0.1.bias', 'binding_site_featurizer.cross_attention.mlp.0.weight', 'binding_site_featurizer.cross_attention.mlp.0.bias', 'binding_site_featurizer.cross_attention.mlp.1.weight', 'binding_site_featurizer.cross_attention.mlp.1.bias', 'binding_site_featurizer.cross_attention.mlp.1.running_mean', 'binding_site_featurizer.cross_attention.mlp.1.running_var', 'binding_site_featurizer.cross_attention.mlp.1.num_batches_tracked', 'binding_site_featurizer.cross_attention.mlp.4.weight', 'binding_site_featurizer.cross_attention.mlp.4.bias', 'binding_site_featurizer.cross_attention.mlp.5.weight', 'binding_site_featurizer.cross_attention.mlp.5.bias', 'binding_site_featurizer.cross_attention.mlp.5.running_mean', 'binding_site_featurizer.cross_attention.mlp.5.running_var', 'binding_site_featurizer.cross_attention.mlp.5.num_batches_tracked', 'binding_site_featurizer.cross_attention.mlp.8.weight', 'binding_site_featurizer.cross_attention.mlp.8.bias']
# Fold 5: 100%|██████████| 4/4 [01:31<00:00, 22.87s/it]
# Original eval: 100%|██████████| 69/69 [00:02<00:00, 31.62it/s]
# Unique ligands in fold 5: 36
#   Swap repetition 1/5 done.
#   Swap repetition 2/5 done.
#   Swap repetition 3/5 done.
#   Swap repetition 4/5 done.
#   Swap repetition 5/5 done.
# Fold 5 done. Entries: 69
#
# ============================================================
# Processing fold 6 (DecoyFinder Decoys — Ligand Swap)
# ============================================================
# Global seed set to 42
# Not loaded: ['smol_binding_featurizer.0.weight', 'smol_binding_featurizer.0.bias', 'smol_binding_featurizer.1.weight', 'smol_binding_featurizer.1.bias', 'smol_binding_featurizer.1.running_mean', 'smol_binding_featurizer.1.running_var', 'smol_binding_featurizer.1.num_batches_tracked', 'binding_site_featurizer.cross_attention.smol_projection.weight', 'binding_site_featurizer.cross_attention.smol_projection.bias', 'binding_site_featurizer.cross_attention.projection.weight', 'binding_site_featurizer.cross_attention.projection.bias', 'binding_site_featurizer.cross_attention.batch_norm_projection.weight', 'binding_site_featurizer.cross_attention.batch_norm_projection.bias', 'binding_site_featurizer.cross_attention.batch_norm_projection.running_mean', 'binding_site_featurizer.cross_attention.batch_norm_projection.running_var', 'binding_site_featurizer.cross_attention.batch_norm_projection.num_batches_tracked', 'binding_site_featurizer.cross_attention.self_attention.0.0.in_proj_weight', 'binding_site_featurizer.cross_attention.self_attention.0.0.in_proj_bias', 'binding_site_featurizer.cross_attention.self_attention.0.0.out_proj.weight', 'binding_site_featurizer.cross_attention.self_attention.0.0.out_proj.bias', 'binding_site_featurizer.cross_attention.self_attention.0.1.weight', 'binding_site_featurizer.cross_attention.self_attention.0.1.bias', 'binding_site_featurizer.cross_attention.mlp.0.weight', 'binding_site_featurizer.cross_attention.mlp.0.bias', 'binding_site_featurizer.cross_attention.mlp.1.weight', 'binding_site_featurizer.cross_attention.mlp.1.bias', 'binding_site_featurizer.cross_attention.mlp.1.running_mean', 'binding_site_featurizer.cross_attention.mlp.1.running_var', 'binding_site_featurizer.cross_attention.mlp.1.num_batches_tracked', 'binding_site_featurizer.cross_attention.mlp.4.weight', 'binding_site_featurizer.cross_attention.mlp.4.bias', 'binding_site_featurizer.cross_attention.mlp.5.weight', 'binding_site_featurizer.cross_attention.mlp.5.bias', 'binding_site_featurizer.cross_attention.mlp.5.running_mean', 'binding_site_featurizer.cross_attention.mlp.5.running_var', 'binding_site_featurizer.cross_attention.mlp.5.num_batches_tracked', 'binding_site_featurizer.cross_attention.mlp.8.weight', 'binding_site_featurizer.cross_attention.mlp.8.bias']
# Fold 6: 100%|██████████| 4/4 [04:30<00:00, 67.66s/it]
# Original eval: 100%|██████████| 76/76 [00:00<00:00, 104.93it/s]
# Unique ligands in fold 6: 34
#   Swap repetition 1/5 done.
#   Swap repetition 2/5 done.
#   Swap repetition 3/5 done.
#   Swap repetition 4/5 done.
#   Swap repetition 5/5 done.
# Fold 6 done. Entries: 76
#
# ============================================================
# Processing fold 7 (DecoyFinder Decoys — Ligand Swap)
# ============================================================
# Global seed set to 42
# Not loaded: ['smol_binding_featurizer.0.weight', 'smol_binding_featurizer.0.bias', 'smol_binding_featurizer.1.weight', 'smol_binding_featurizer.1.bias', 'smol_binding_featurizer.1.running_mean', 'smol_binding_featurizer.1.running_var', 'smol_binding_featurizer.1.num_batches_tracked', 'binding_site_featurizer.cross_attention.smol_projection.weight', 'binding_site_featurizer.cross_attention.smol_projection.bias', 'binding_site_featurizer.cross_attention.projection.weight', 'binding_site_featurizer.cross_attention.projection.bias', 'binding_site_featurizer.cross_attention.batch_norm_projection.weight', 'binding_site_featurizer.cross_attention.batch_norm_projection.bias', 'binding_site_featurizer.cross_attention.batch_norm_projection.running_mean', 'binding_site_featurizer.cross_attention.batch_norm_projection.running_var', 'binding_site_featurizer.cross_attention.batch_norm_projection.num_batches_tracked', 'binding_site_featurizer.cross_attention.self_attention.0.0.in_proj_weight', 'binding_site_featurizer.cross_attention.self_attention.0.0.in_proj_bias', 'binding_site_featurizer.cross_attention.self_attention.0.0.out_proj.weight', 'binding_site_featurizer.cross_attention.self_attention.0.0.out_proj.bias', 'binding_site_featurizer.cross_attention.self_attention.0.1.weight', 'binding_site_featurizer.cross_attention.self_attention.0.1.bias', 'binding_site_featurizer.cross_attention.mlp.0.weight', 'binding_site_featurizer.cross_attention.mlp.0.bias', 'binding_site_featurizer.cross_attention.mlp.1.weight', 'binding_site_featurizer.cross_attention.mlp.1.bias', 'binding_site_featurizer.cross_attention.mlp.1.running_mean', 'binding_site_featurizer.cross_attention.mlp.1.running_var', 'binding_site_featurizer.cross_attention.mlp.1.num_batches_tracked', 'binding_site_featurizer.cross_attention.mlp.4.weight', 'binding_site_featurizer.cross_attention.mlp.4.bias', 'binding_site_featurizer.cross_attention.mlp.5.weight', 'binding_site_featurizer.cross_attention.mlp.5.bias', 'binding_site_featurizer.cross_attention.mlp.5.running_mean', 'binding_site_featurizer.cross_attention.mlp.5.running_var', 'binding_site_featurizer.cross_attention.mlp.5.num_batches_tracked', 'binding_site_featurizer.cross_attention.mlp.8.weight', 'binding_site_featurizer.cross_attention.mlp.8.bias']
# Fold 7: 100%|██████████| 4/4 [00:47<00:00, 11.91s/it]
# Original eval: 100%|██████████| 72/72 [00:01<00:00, 67.23it/s]
# Unique ligands in fold 7: 35
#   Swap repetition 1/5 done.
#   Swap repetition 2/5 done.
#   Swap repetition 3/5 done.
#   Swap repetition 4/5 done.
#   Swap repetition 5/5 done.
# Fold 7 done. Entries: 72
#
# ============================================================
# Processing fold 8 (DecoyFinder Decoys — Ligand Swap)
# ============================================================
# Global seed set to 42
# Not loaded: ['smol_binding_featurizer.0.weight', 'smol_binding_featurizer.0.bias', 'smol_binding_featurizer.1.weight', 'smol_binding_featurizer.1.bias', 'smol_binding_featurizer.1.running_mean', 'smol_binding_featurizer.1.running_var', 'smol_binding_featurizer.1.num_batches_tracked', 'binding_site_featurizer.cross_attention.smol_projection.weight', 'binding_site_featurizer.cross_attention.smol_projection.bias', 'binding_site_featurizer.cross_attention.projection.weight', 'binding_site_featurizer.cross_attention.projection.bias', 'binding_site_featurizer.cross_attention.batch_norm_projection.weight', 'binding_site_featurizer.cross_attention.batch_norm_projection.bias', 'binding_site_featurizer.cross_attention.batch_norm_projection.running_mean', 'binding_site_featurizer.cross_attention.batch_norm_projection.running_var', 'binding_site_featurizer.cross_attention.batch_norm_projection.num_batches_tracked', 'binding_site_featurizer.cross_attention.self_attention.0.0.in_proj_weight', 'binding_site_featurizer.cross_attention.self_attention.0.0.in_proj_bias', 'binding_site_featurizer.cross_attention.self_attention.0.0.out_proj.weight', 'binding_site_featurizer.cross_attention.self_attention.0.0.out_proj.bias', 'binding_site_featurizer.cross_attention.self_attention.0.1.weight', 'binding_site_featurizer.cross_attention.self_attention.0.1.bias', 'binding_site_featurizer.cross_attention.mlp.0.weight', 'binding_site_featurizer.cross_attention.mlp.0.bias', 'binding_site_featurizer.cross_attention.mlp.1.weight', 'binding_site_featurizer.cross_attention.mlp.1.bias', 'binding_site_featurizer.cross_attention.mlp.1.running_mean', 'binding_site_featurizer.cross_attention.mlp.1.running_var', 'binding_site_featurizer.cross_attention.mlp.1.num_batches_tracked', 'binding_site_featurizer.cross_attention.mlp.4.weight', 'binding_site_featurizer.cross_attention.mlp.4.bias', 'binding_site_featurizer.cross_attention.mlp.5.weight', 'binding_site_featurizer.cross_attention.mlp.5.bias', 'binding_site_featurizer.cross_attention.mlp.5.running_mean', 'binding_site_featurizer.cross_attention.mlp.5.running_var', 'binding_site_featurizer.cross_attention.mlp.5.num_batches_tracked', 'binding_site_featurizer.cross_attention.mlp.8.weight', 'binding_site_featurizer.cross_attention.mlp.8.bias']
# Fold 8: 100%|██████████| 4/4 [00:45<00:00, 11.28s/it]
# Original eval: 100%|██████████| 70/70 [00:01<00:00, 60.27it/s]
# Unique ligands in fold 8: 25
#   Swap repetition 1/5 done.
#   Swap repetition 2/5 done.
#   Swap repetition 3/5 done.
#   Swap repetition 4/5 done.
#   Swap repetition 5/5 done.
# Fold 8 done. Entries: 70
#
# ============================================================
# Processing fold 9 (DecoyFinder Decoys — Ligand Swap)
# ============================================================
# Global seed set to 42
# Not loaded: ['smol_binding_featurizer.0.weight', 'smol_binding_featurizer.0.bias', 'smol_binding_featurizer.1.weight', 'smol_binding_featurizer.1.bias', 'smol_binding_featurizer.1.running_mean', 'smol_binding_featurizer.1.running_var', 'smol_binding_featurizer.1.num_batches_tracked', 'binding_site_featurizer.cross_attention.smol_projection.weight', 'binding_site_featurizer.cross_attention.smol_projection.bias', 'binding_site_featurizer.cross_attention.projection.weight', 'binding_site_featurizer.cross_attention.projection.bias', 'binding_site_featurizer.cross_attention.batch_norm_projection.weight', 'binding_site_featurizer.cross_attention.batch_norm_projection.bias', 'binding_site_featurizer.cross_attention.batch_norm_projection.running_mean', 'binding_site_featurizer.cross_attention.batch_norm_projection.running_var', 'binding_site_featurizer.cross_attention.batch_norm_projection.num_batches_tracked', 'binding_site_featurizer.cross_attention.self_attention.0.0.in_proj_weight', 'binding_site_featurizer.cross_attention.self_attention.0.0.in_proj_bias', 'binding_site_featurizer.cross_attention.self_attention.0.0.out_proj.weight', 'binding_site_featurizer.cross_attention.self_attention.0.0.out_proj.bias', 'binding_site_featurizer.cross_attention.self_attention.0.1.weight', 'binding_site_featurizer.cross_attention.self_attention.0.1.bias', 'binding_site_featurizer.cross_attention.mlp.0.weight', 'binding_site_featurizer.cross_attention.mlp.0.bias', 'binding_site_featurizer.cross_attention.mlp.1.weight', 'binding_site_featurizer.cross_attention.mlp.1.bias', 'binding_site_featurizer.cross_attention.mlp.1.running_mean', 'binding_site_featurizer.cross_attention.mlp.1.running_var', 'binding_site_featurizer.cross_attention.mlp.1.num_batches_tracked', 'binding_site_featurizer.cross_attention.mlp.4.weight', 'binding_site_featurizer.cross_attention.mlp.4.bias', 'binding_site_featurizer.cross_attention.mlp.5.weight', 'binding_site_featurizer.cross_attention.mlp.5.bias', 'binding_site_featurizer.cross_attention.mlp.5.running_mean', 'binding_site_featurizer.cross_attention.mlp.5.running_var', 'binding_site_featurizer.cross_attention.mlp.5.num_batches_tracked', 'binding_site_featurizer.cross_attention.mlp.8.weight', 'binding_site_featurizer.cross_attention.mlp.8.bias']
# Fold 9: 100%|██████████| 4/4 [00:58<00:00, 14.59s/it]
# Original eval: 100%|██████████| 75/75 [00:01<00:00, 66.76it/s]
# Unique ligands in fold 9: 36
#   Swap repetition 1/5 done.
#   Swap repetition 2/5 done.
#   Swap repetition 3/5 done.
#   Swap repetition 4/5 done.
#   Swap repetition 5/5 done.
# Fold 9 done. Entries: 75
#
# ============================================================
# Processing fold 10 (DecoyFinder Decoys — Ligand Swap)
# ============================================================
# Global seed set to 42
# Not loaded: ['smol_binding_featurizer.0.weight', 'smol_binding_featurizer.0.bias', 'smol_binding_featurizer.1.weight', 'smol_binding_featurizer.1.bias', 'smol_binding_featurizer.1.running_mean', 'smol_binding_featurizer.1.running_var', 'smol_binding_featurizer.1.num_batches_tracked', 'binding_site_featurizer.cross_attention.smol_projection.weight', 'binding_site_featurizer.cross_attention.smol_projection.bias', 'binding_site_featurizer.cross_attention.projection.weight', 'binding_site_featurizer.cross_attention.projection.bias', 'binding_site_featurizer.cross_attention.batch_norm_projection.weight', 'binding_site_featurizer.cross_attention.batch_norm_projection.bias', 'binding_site_featurizer.cross_attention.batch_norm_projection.running_mean', 'binding_site_featurizer.cross_attention.batch_norm_projection.running_var', 'binding_site_featurizer.cross_attention.batch_norm_projection.num_batches_tracked', 'binding_site_featurizer.cross_attention.self_attention.0.0.in_proj_weight', 'binding_site_featurizer.cross_attention.self_attention.0.0.in_proj_bias', 'binding_site_featurizer.cross_attention.self_attention.0.0.out_proj.weight', 'binding_site_featurizer.cross_attention.self_attention.0.0.out_proj.bias', 'binding_site_featurizer.cross_attention.self_attention.0.1.weight', 'binding_site_featurizer.cross_attention.self_attention.0.1.bias', 'binding_site_featurizer.cross_attention.mlp.0.weight', 'binding_site_featurizer.cross_attention.mlp.0.bias', 'binding_site_featurizer.cross_attention.mlp.1.weight', 'binding_site_featurizer.cross_attention.mlp.1.bias', 'binding_site_featurizer.cross_attention.mlp.1.running_mean', 'binding_site_featurizer.cross_attention.mlp.1.running_var', 'binding_site_featurizer.cross_attention.mlp.1.num_batches_tracked', 'binding_site_featurizer.cross_attention.mlp.4.weight', 'binding_site_featurizer.cross_attention.mlp.4.bias', 'binding_site_featurizer.cross_attention.mlp.5.weight', 'binding_site_featurizer.cross_attention.mlp.5.bias', 'binding_site_featurizer.cross_attention.mlp.5.running_mean', 'binding_site_featurizer.cross_attention.mlp.5.running_var', 'binding_site_featurizer.cross_attention.mlp.5.num_batches_tracked', 'binding_site_featurizer.cross_attention.mlp.8.weight', 'binding_site_featurizer.cross_attention.mlp.8.bias']
# Fold 10: 100%|██████████| 4/4 [00:42<00:00, 10.60s/it]
# Original eval: 100%|██████████| 75/75 [00:00<00:00, 145.38it/s]
# Unique ligands in fold 10: 52
#   Swap repetition 1/5 done.
#   Swap repetition 2/5 done.
#   Swap repetition 3/5 done.
#   Swap repetition 4/5 done.
#   Swap repetition 5/5 done.
# Fold 10 done. Entries: 75

# %% [markdown]
# ### DecoyFinder — Target-level (Local) AuROC

# %%
# ============================================================
# DecoyFinder — Target-level (Local) AuROC Ligand Swap Analysis
# ============================================================

print('\n' + '='*70)
print('TARGET-LEVEL (LOCAL) AuROC LIGAND SWAP — DecoyFinder Decoys')
print('='*70)

all_local_auc_original_df = []
all_local_auc_swapped_per_k_df = [[] for _ in range(K_SWAP_REPETITIONS)]
all_local_rp_original_df = []
all_local_rp_swapped_per_k_df = [[] for _ in range(K_SWAP_REPETITIONS)]

for fold_num in range(1, 11):
    res = all_fold_results_df[fold_num]
    rna_names = res['rna_names']
    
    target_aurocs_orig = defaultdict(list)
    target_rps_orig = defaultdict(list)
    for i, rn in enumerate(rna_names):
        target_rps_orig[rn].append(res['original_rank_percentiles'][i])
        target_aurocs_orig[rn].append(res['original_pair_aurocs'][i])
    
    valid_target_aurocs_orig = [np.mean(aurocs) for aurocs in target_aurocs_orig.values()]
    fold_local_auc_orig = np.mean(valid_target_aurocs_orig)
    fold_local_rp_orig = np.mean([np.mean(rps) for rps in target_rps_orig.values()])
    all_local_auc_original_df.append(fold_local_auc_orig)
    all_local_rp_original_df.append(fold_local_rp_orig)
    
    for k in range(K_SWAP_REPETITIONS):
        swap_res = res['swap_rep_results'][k]
        target_aurocs_swap = defaultdict(list)
        target_rps_swap = defaultdict(list)
        for i, rn in enumerate(rna_names):
            target_aurocs_swap[rn].append(swap_res['pair_aurocs'][i])
            target_rps_swap[rn].append(swap_res['rank_percentiles'][i])
        
        valid_target_aurocs_swap = [np.mean(aurocs) for aurocs in target_aurocs_swap.values()]
        all_local_auc_swapped_per_k_df[k].append(np.mean(valid_target_aurocs_swap))
        all_local_rp_swapped_per_k_df[k].append(np.mean([np.mean(rps) for rps in target_rps_swap.values()]))
    
    print(f'Fold {fold_num}: Local AuROC original = {fold_local_auc_orig:.4f}')

local_auc_original_df = np.mean(all_local_auc_original_df)
local_auc_original_std_df = np.std(all_local_auc_original_df, ddof=1)
local_rp_original_df = np.mean(all_local_rp_original_df)
local_rp_original_std_df = np.std(all_local_rp_original_df, ddof=1)

# Flat per-pair stats for reference
all_pair_aurocs_flat_df = []
all_pair_rps_flat_df = []
for fold_num in range(1, 11):
    res = all_fold_results_df[fold_num]
    all_pair_aurocs_flat_df.extend(res['original_pair_aurocs'])
    all_pair_rps_flat_df.extend(res['original_rank_percentiles'])
flat_auc_mean_df = np.mean(all_pair_aurocs_flat_df)
flat_auc_std_df = np.std(all_pair_aurocs_flat_df, ddof=1)
flat_rp_mean_df = np.mean(all_pair_rps_flat_df)
flat_rp_std_df = np.std(all_pair_rps_flat_df, ddof=1)

local_auc_swapped_per_k_df = [np.mean(all_local_auc_swapped_per_k_df[k]) for k in range(K_SWAP_REPETITIONS)]
local_rp_swapped_per_k_df = [np.mean(all_local_rp_swapped_per_k_df[k]) for k in range(K_SWAP_REPETITIONS)]

local_auc_swapped_mean_df = np.mean(local_auc_swapped_per_k_df)
local_auc_swapped_std_df = np.std(local_auc_swapped_per_k_df, ddof=1)
local_rp_swapped_mean_df = np.mean(local_rp_swapped_per_k_df)
local_rp_swapped_std_df = np.std(local_rp_swapped_per_k_df, ddof=1)

# Per-k performance gap
gap_local_auc_per_k_df = [100 * (local_auc_swapped_per_k_df[k] - local_auc_original_df) / local_auc_original_df for k in range(K_SWAP_REPETITIONS)]
gap_local_rp_per_k_df = [100 * (local_rp_swapped_per_k_df[k] - local_rp_original_df) / local_rp_original_df for k in range(K_SWAP_REPETITIONS)]
gap_local_auc_mean_df = np.mean(gap_local_auc_per_k_df)
gap_local_auc_std_df = np.std(gap_local_auc_per_k_df, ddof=1)
gap_local_rp_mean_df = np.mean(gap_local_rp_per_k_df)
gap_local_rp_std_df = np.std(gap_local_rp_per_k_df, ddof=1)

print(f'\n=== Target-level (Local) Results — DecoyFinder Decoys (Ligand Swap) ===')
print(f'Original  Local AuROC: {local_auc_original_df:.4f} ± {local_auc_original_std_df:.4f} (across 10 folds)')
print(f'Swapped   Local AuROC: {local_auc_swapped_mean_df:.4f} ± {local_auc_swapped_std_df:.4f} (K={K_SWAP_REPETITIONS})')
print(f'Performance Gap:       {gap_local_auc_mean_df:.2f}% ± {gap_local_auc_std_df:.2f}%')
print(f'\nOriginal  Local Rank Percentile: {local_rp_original_df:.4f} ± {local_rp_original_std_df:.4f} (across 10 folds)')
print(f'Swapped   Local Rank Percentile: {local_rp_swapped_mean_df:.4f} ± {local_rp_swapped_std_df:.4f}')
print(f'Performance Gap:                 {gap_local_rp_mean_df:.2f}% ± {gap_local_rp_std_df:.2f}%')
print(f'\n--- Flat per-pair stats (for reference) ---')
print(f'Total pairs: {len(all_pair_aurocs_flat_df)}')
print(f'Flat Mean Rank Percentile: {flat_rp_mean_df:.4f} ± {flat_rp_std_df:.4f}')
print(f'Flat Mean Per-pair AUROC:  {flat_auc_mean_df:.4f} ± {flat_auc_std_df:.4f}')
# Out:
# ======================================================================
# TARGET-LEVEL (LOCAL) AuROC LIGAND SWAP — DecoyFinder Decoys
# ======================================================================
# Fold 1: Local AuROC original = 0.8634
# Fold 2: Local AuROC original = 0.7813
# Fold 3: Local AuROC original = 0.9004
# Fold 4: Local AuROC original = 0.9222
# Fold 5: Local AuROC original = 0.9381
# Fold 6: Local AuROC original = 0.8910
# Fold 7: Local AuROC original = 0.9195
# Fold 8: Local AuROC original = 0.8927
# Fold 9: Local AuROC original = 0.9007
# Fold 10: Local AuROC original = 0.7491
#
# === Target-level (Local) Results — DecoyFinder Decoys (Ligand Swap) ===
# Original  Local AuROC: 0.8758 ± 0.0622 (across 10 folds)
# Swapped   Local AuROC: 0.5677 ± 0.0396 (K=5)
# Performance Gap:       -35.18% ± 4.52%
#
# Original  Local Rank Percentile: 0.8859 ± 0.0537 (across 10 folds)
# Swapped   Local Rank Percentile: 0.6366 ± 0.0252
# Performance Gap:                 -28.14% ± 2.84%
#
# --- Flat per-pair stats (for reference) ---
# Total pairs: 717
# Flat Mean Rank Percentile: 0.8795 ± 0.2040
# Flat Mean Per-pair AUROC:  0.8688 ± 0.2278

# %% [markdown]
# ### DecoyFinder — Global AuROC

# %%
# ============================================================
# DecoyFinder — Global AuROC Ligand Swap Analysis
# ============================================================

print('\n' + '='*70)
print('GLOBAL AuROC LIGAND SWAP — DecoyFinder Decoys')
print('='*70)

all_global_auc_original_df = []
all_global_auc_swapped_per_k_df = [[] for _ in range(K_SWAP_REPETITIONS)]

for fold_num in range(1, 11):
    res = all_fold_results_df[fold_num]
    
    all_labels = []
    all_scores = []
    for match_score, decoy_scores in res['original_scores']:
        all_scores.append(match_score)
        all_labels.append(1)
        for ds in decoy_scores:
            all_scores.append(ds)
            all_labels.append(0)
    
    all_scores_norm = normalize_scores(all_scores)
    fold_global_auc_orig = roc_auc_score(all_labels, all_scores_norm)
    all_global_auc_original_df.append(fold_global_auc_orig)
    
    for k in range(K_SWAP_REPETITIONS):
        swap_res = res['swap_rep_results'][k]
        all_labels_s = []
        all_scores_s = []
        for match_score, decoy_scores in swap_res['scores']:
            all_scores_s.append(match_score)
            all_labels_s.append(1)
            for ds in decoy_scores:
                all_scores_s.append(ds)
                all_labels_s.append(0)
        
        all_scores_s_norm = normalize_scores(all_scores_s)
        fold_global_auc_swap = roc_auc_score(all_labels_s, all_scores_s_norm)
        all_global_auc_swapped_per_k_df[k].append(fold_global_auc_swap)
    
    print(f'Fold {fold_num}: Global AuROC original = {fold_global_auc_orig:.4f}')

global_auc_original_df = np.mean(all_global_auc_original_df)
global_auc_swapped_per_k_df = [np.mean(all_global_auc_swapped_per_k_df[k]) for k in range(K_SWAP_REPETITIONS)]
global_auc_swapped_mean_df = np.mean(global_auc_swapped_per_k_df)
global_auc_swapped_std_df = np.std(global_auc_swapped_per_k_df, ddof=1)

# Per-k performance gap
gap_global_auc_per_k_df = [100 * (global_auc_swapped_per_k_df[k] - global_auc_original_df) / global_auc_original_df for k in range(K_SWAP_REPETITIONS)]
gap_global_auc_mean_df = np.mean(gap_global_auc_per_k_df)
gap_global_auc_std_df = np.std(gap_global_auc_per_k_df, ddof=1)

print(f'\n=== Global Results — DecoyFinder Decoys (Ligand Swap) ===')
print(f'Original  Global AuROC: {global_auc_original_df:.4f}')
print(f'Swapped   Global AuROC: {global_auc_swapped_mean_df:.4f} ± {global_auc_swapped_std_df:.4f} (K={K_SWAP_REPETITIONS})')
print(f'Performance Gap:        {gap_global_auc_mean_df:.2f}% ± {gap_global_auc_std_df:.2f}%')
# Out:
# ======================================================================
# GLOBAL AuROC LIGAND SWAP — DecoyFinder Decoys
# ======================================================================
# Fold 1: Global AuROC original = 0.8384
# Fold 2: Global AuROC original = 0.8173
# Fold 3: Global AuROC original = 0.8726
# Fold 4: Global AuROC original = 0.8969
# Fold 5: Global AuROC original = 0.9464
# Fold 6: Global AuROC original = 0.8147
# Fold 7: Global AuROC original = 0.8596
# Fold 8: Global AuROC original = 0.8501
# Fold 9: Global AuROC original = 0.8308
# Fold 10: Global AuROC original = 0.6568
#
# === Global Results — DecoyFinder Decoys (Ligand Swap) ===
# Original  Global AuROC: 0.8384
# Swapped   Global AuROC: 0.5972 ± 0.0200 (K=5)
# Performance Gap:        -28.77% ± 2.38%

# %% [markdown]
# ---
# ## Summary Table

# %%
print('\n' + '='*90)
print('SUMMARY TABLE — LIGAND SWAP')
print('='*90)
print(f'{"":<35} {"Original":>12} {"Swapped":>20} {"Gap (%)":>18}')
print('-'*90)

# PDB Decoys
print(f'{"PDB — Target-level AuROC":<35} {local_auc_original:>12.4f} {local_auc_swapped_mean:>10.4f} ± {local_auc_swapped_std:.4f} {gap_local_auc_mean:>8.2f} ± {gap_local_auc_std:.2f}')
print(f'{"PDB — Target-level Rank %":<35} {local_rp_original:>12.4f} {local_rp_swapped_mean:>10.4f} ± {local_rp_swapped_std:.4f} {gap_local_rp_mean:>8.2f} ± {gap_local_rp_std:.2f}')
print(f'{"PDB — Global AuROC":<35} {global_auc_original:>12.4f} {global_auc_swapped_mean:>10.4f} ± {global_auc_swapped_std:.4f} {gap_global_auc_mean:>8.2f} ± {gap_global_auc_std:.2f}')
print()

# DecoyFinder Decoys
print(f'{"DF — Target-level AuROC":<35} {local_auc_original_df:>12.4f} {local_auc_swapped_mean_df:>10.4f} ± {local_auc_swapped_std_df:.4f} {gap_local_auc_mean_df:>8.2f} ± {gap_local_auc_std_df:.2f}')
print(f'{"DF — Target-level Rank %":<35} {local_rp_original_df:>12.4f} {local_rp_swapped_mean_df:>10.4f} ± {local_rp_swapped_std_df:.4f} {gap_local_rp_mean_df:>8.2f} ± {gap_local_rp_std_df:.2f}')
print(f'{"DF — Global AuROC":<35} {global_auc_original_df:>12.4f} {global_auc_swapped_mean_df:>10.4f} ± {global_auc_swapped_std_df:.4f} {gap_global_auc_mean_df:>8.2f} ± {gap_global_auc_std_df:.2f}')
# Out:
# ==========================================================================================
# SUMMARY TABLE — LIGAND SWAP
# ==========================================================================================
#                                         Original              Swapped            Gap (%)
# ------------------------------------------------------------------------------------------
# PDB — Target-level AuROC                  0.8239     0.5046 ± 0.0132   -38.75 ± 1.60
# PDB — Target-level Rank %                 0.8274     0.5122 ± 0.0126   -38.09 ± 1.53
# PDB — Global AuROC                        0.8157     0.5080 ± 0.0101   -37.72 ± 1.24
#
# DF — Target-level AuROC                   0.8758     0.5677 ± 0.0396   -35.18 ± 4.52
# DF — Target-level Rank %                  0.8859     0.6366 ± 0.0252   -28.14 ± 2.84
# DF — Global AuROC                         0.8384     0.5972 ± 0.0200   -28.77 ± 2.38
